# %%
#Name: Luu Hoang Long Vo & Phu Hien Le
#UID: 23611 & 23607

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.3)

# %%
from pyspark.sql import SparkSession
import pandas as pd
from pyspark.sql.types import *

# %%
spark_application_name = "Spark_Application_Name"

# %%
spark = (SparkSession.builder.appName(spark_application_name).getOrCreate())

# %% [markdown]
# # Preliminary
#
# ## Create helper function
#
# ### `dfs_execution`
#
# - Helper function to help execute a given functions on all dfs

# %%
def dfs_execution(list_df, list_name, func):
  list_exec_dfs = []
  for df, name in zip(list_df, list_name):
    print(name)
    list_exec_dfs.append(func(df))
    print('')
  return list_exec_dfs

# %% [markdown]
# ### `read_disp_info`
#
# - Helper function to help read and set the appropriate column to the given name and types
# - Also print the schema of each df
# - First 40 rows and last 40 rows are also displayed

# %%
def read_disp_info(file, delimiter = ',', header = True):
    
    devColumns = [StructField("Date",TimestampType()), StructField("High",FloatType()), StructField("Low",FloatType()), StructField("Open",FloatType()),StructField("Close",FloatType()),StructField("Volume",LongType()), StructField("Adj Close",FloatType()), StructField("company_name",StringType()) ]
    devSchema = StructType(devColumns)
    df = spark.read.options(header=header, delimiter=delimiter).csv(file, schema= devSchema)
    df.printSchema()
    print(df.head(40))
    print(df.tail(40))
    print(df.count())
    return df

# %% [markdown]
# # Finding the number of dates that separate between each other

# %%
def time_period(date_one, date_two):
    return date_two - date_one

# %% [markdown]
# # Describe each of the df by using `Dataframe.describe()`

# %%
def describe_df(df):
  df.describe().show(n=10)

# %% [markdown]
# # Count missing value (`NAs`, `Null`)
#
# - Using aggregrate function `F.count()` with the given condition of checking missing value, create a new df containing the columns and the number of its missing value

# %%
import pyspark.sql.functions as F

def count_missing_alt(df):
  df = df.drop('Date')
  df.select([F.count(F.when(F.isnan(c) | F.isnull(c), c)).alias(c) for c in df.columns]).show(n=10)

# %% [markdown]
# # Correlation
#
# - Take the correlation between each columns once with the help of the function `Dataframe.corr()`

# %%
def correlation(df):
  df = df.drop('Date', 'company_name')
  columns = df.columns
  for i in range (len(columns)):
    for j in range (i+1, len(columns)):
      print(f"{columns[i]} & {columns[j]}: {str(df.corr(columns[i], columns[j]))}")

# %% [markdown]
# # Average opening and closing price:
#
# - Given a `start_date` & an `end_date`
#     - Filter the rows within the given timeframe
#     - Use aggregrate function `F.avg()` to extract the average of the desired column (`Open`, `Close`)
#     - Check if it exist the average, if it exists then print it out to the output stream

# %%
def avg_opening_closing_prices(df, start_date, end_date):
    df = df.filter(F.col("Date").between(start_date, end_date))
    open_avg = df.select(F.avg('Open')).collect()
    close_avg = df.select(F.avg('Close')).collect()
    if (len(open_avg) == 1 and len(close_avg) == 1):
      if open_avg[0]['avg(Open)']:
        print(f"Open average price: {round(open_avg[0]['avg(Open)'], 2)}")
        print(f"Close average price: {round(close_avg[0]['avg(Close)'], 2)}")
      else:
        print("No data for existing company")

def avg_open_close_wrapper(df):
    avg_opening_closing_prices(df, '2017-01-03','2017-01-09')

# %% [markdown]
# #Stock price change
#
# ## Stock price day to day change
#
# - Create a `Window` that is ordered by `Date`
# - Loop through each of the columns that are in the `df`
# - For each column creates a separate new column `prev_value` that represents the value of the column that is being looped but one day before
# - Create the diff column by minus the original column and the `prev_value`
# - Return a new `df` containing only the daily diff of each column

# %%
from pyspark.sql.window import Window

def stock_prices_day_to_day_change(df):
  my_window = Window.partitionBy().orderBy("Date")

  columns = ['High', 'Low', 'Open', 'Close', 'Adj Close']
  for col in columns:
    df = df.withColumn("prev_value", F.lag(df[col]).over(my_window))
    df = df.withColumn(f"{col} diff", F.when(F.isnull(df[col] - df.prev_value), 0)
                              .otherwise(df[col] - df.prev_value))
  df = df.drop(*columns, 'prev_value') 
  df.show(n=10)

# %% [markdown]
# ## Stock price change monthly
#
# - Extract all the distinct `years` and `months` from the dataframe
# - Filter all the entries that exist within the given month and year
# - Take the row containing the first day of the month of each month
# - Find the difference between the two rows of two consecutive months to see the difference
# - Store the difference in to a `monthly` dataframe

# %%
def stock_prices_delta_monthly(df):
    df = df.drop('Volume')
    years = df.select(F.year('Date')).distinct().collect()
    months = df.select(F.month('Date')).distinct().collect()
    lst = []
    for year in years:
        for month in months:
            lst.append(df.filter((F.year('Date') == year[0]) & (F.month('Date') == month[0])).collect())

    monthly_data = []
    for month in lst:
        if len(month) >= 1:
            monthly_data.append(month[0])
        
    monthly = spark.createDataFrame(monthly_data)
    
    my_window = Window.partitionBy().orderBy("Date")

    columns = ['High', 'Low', 'Open', 'Close', 'Adj Close']
    for col in columns:
        monthly = monthly.withColumn("prev_value", F.lag(monthly[col]).over(my_window))
        monthly = monthly.withColumn(f"{col} diff", F.when(F.isnull(monthly[col] - monthly.prev_value), 0)
                              .otherwise(monthly[col] - monthly.prev_value))
    
    monthly = monthly.drop(*columns, 'prev_value')
    monthly.show(n=10)

# %% [markdown]
# # Daily Return
# - Create a new column that contains the `daily_return` value that is named `Daily Return`
# - Formula of `Daily Return` is `Opening Price - Closing Price = Daily Return`

# %%
def daily_return(df):
    df = df.withColumn("Daily Return", F.when(F.isnull(df['Open'] - df['Close']), 0)
                              .otherwise(df['Open'] - df['Close']))
    df.show(n=10)
    return df

# %% [markdown]
# # Highest Daily Return
#
# - Combine all the existing stocks dataframes in to one big dataframe and then reindex the dataframe by `Date` column
# - Extract all the unique dates exist in the dataframe
# - For each of the date, extract the list of all the stocks that were traded on that date and select the one with the highest `daily_return` value
# - Added the row with the highest value into a list and at the end create a new dataframe containing all highest `daily_return` for all dates

# %%
def highest_daily_return(list_df, n_days = None):
    total_stocks = None
    for df in list_df:
        if not total_stocks:
            total_stocks = df
        else:
            total_stocks = total_stocks.union(df)
    dates = total_stocks.select('Date').distinct().sort('Date').collect()
    print(len(dates))
    total_stocks = total_stocks.sort('Date')
    highest_daily_return = []
    for index, date in enumerate(dates):
        if n_days and index == n_days:
            break
        daily_return = total_stocks.select('Daily Return', 'company_name', 'Date').where(total_stocks['Date'] == date['Date'])
        w = Window.partitionBy('Date')
        highest_daily = daily_return.withColumn('maxDailyReturn', F.max('Daily Return').over(w))\
        .where(F.col('Daily Return') == F.col('maxDailyReturn'))\
        .drop('maxDailyReturn')\
        .collect()
        highest_daily_return += highest_daily
    
    return spark.createDataFrame(highest_daily_return)

# %% [markdown]
# # Average daily return for different period of time (weekly, monthly, yearly)
#
# ## Monthly average daily return
#
# - Extract all the distinct `years` and `months` from the dataframe
# - Filter all the entries that exist within the given month and year
# - Deduce the average of that by the aggregrate function `F.avg()`
# - Append the given row into a `lst`
# - Create a dataframe at the end containing all the average `daily_return` of each month that exist in the `df`

# %%
def avg_daily_return_month(df):
    df = df.drop('High','Low','Open','Close','Volume','Adj Close','company_name')
    years = df.select(F.year('Date')).distinct().sort('Date').collect()
    months = df.select(F.month('Date')).distinct().sort('Date').collect()
    lst = []
    for year in years:
        for month in months:
            df_monthly = df.filter((F.year('Date') == year[0]) & (F.month('Date') == month[0]))
            lst.append(df_monthly.select(F.avg('Daily Return')).collect()[0])
    dates = []
    for year in years:
        for month in months:
            dates.append(f"{month[0]} - {year[0]}")
    monthly_return_avg_df = spark.createDataFrame(data=lst)
    monthly_return_avg_df = monthly_return_avg_df.repartition(1).withColumn("Month & Year", F.udf(lambda id: dates[id])(F.monotonically_increasing_id()))
    monthly_return_avg_df.show(n=10)

# %% [markdown]
# ## Yearly average daily return
#
# - Extract all the distinct `years` from the dataframe
# - Filter all the entries that exist within the year
# - Deduce the average of that by the aggregrate function `F.avg()`
# - Append the given row into a `lst`
# - Create a dataframe at the end containing all the average `daily_return` of each year that exist in the `df`

# %%
def avg_daily_return_year(df):
    df = df.drop('High','Low','Open','Close','Volume','Adj Close','company_name')
    years = df.select(F.year('Date')).distinct().sort('Date').collect()
    lst = []
    lst_dates = []
    for year in years:
          df_yearly = df.filter((F.year('Date') == year[0]))
          lst_dates.append(df_yearly.select(F.year('Date')).collect()[0])
          lst.append(df_yearly.select(F.avg('Daily Return')).collect()[0])

    dates = []
    for year in years:
        dates.append(year['year(Date)'])
    yearly_return_avg_df = spark.createDataFrame(data=lst)
    yearly_return_avg_df = yearly_return_avg_df.repartition(1).withColumn("Year", F.udf(lambda id: dates[id])(F.monotonically_increasing_id()))
    yearly_return_avg_df.show(n=10)

# %% [markdown]
# ## Weekly average daily return
#
# - Extract all the distinct `years` and `weeks` from the dataframe
# - Filter all the entries that exist within the given week and year
# - Deduce the average of that by the aggregrate function `F.avg()`
# - Append the given row into a `lst`
# - Create a dataframe at the end containing all the average `daily_return` of each week that exist in the `df`

# %%
def avg_daily_return_week(df):
    df = df.drop('High','Low','Open','Close','Volume','Adj Close','company_name')
    years = df.select(F.year('Date')).distinct().sort('Date').collect()
    weeks = df.select(F.weekofyear('Date')).distinct().sort(F.weekofyear('Date')).collect()
    lst = []
    dates = []
    for year in years:
        for week in weeks:
            df_weekly = df.filter((F.year('Date') == year[0]) & (F.weekofyear('Date') == week[0]))
            beginning_date = df_weekly.tail(1)
            if len(beginning_date) >= 1:
                lst.append(df_weekly.select(F.avg('Daily Return')).collect()[0])
                dates.append(beginning_date[0]['Date'].strftime('%d-%m-%Y'))
    weekly_return_avg_df = spark.createDataFrame(data=lst)
    weekly_return_avg_df = weekly_return_avg_df.repartition(1).withColumn("Week & Year", F.udf(lambda id: dates[id])(F.monotonically_increasing_id()))
    weekly_return_avg_df.show(n=10)

# %% [markdown]
# # Moving average
#
# - Create a `Window` that takes the nearest `n` previous values
# - Using the aggregrate function `F.avg()` to find the average value over a certain number `n` previous datapoints
# - Added the average to a new column `moving_average`

# %%
def moving_average(dataframe, column_name, n): 
    #df = dataframe.withColumn('Date', dataframe.timestampGMT.cast('timestamp'))
    w = Window.orderBy(dataframe["Date"].cast('long')).rangeBetween(-(n), 0)
    dataframe = dataframe.withColumn('moving_average', F.avg(column_name).over(w))
    dataframe.show(n=10)

def moving_average_wrapper(df):
  moving_average(df, 'Open', 5)

# %% [markdown]
# # Correlation between stocks
# - Concatenate two given dataframes into one dataframe
# - Use `corr` to calculate correlation between 2 columns of the 2 stocks, which is exactly 6 index apart in the new dataframe.

# %%
def concat_dfs(df1, df2):
    df_temp1 = df1.select('*')
    df_temp2 = df2.selectExpr("Date", "High as High2", "Low as Low2", "Open as Open2", "Close as Close2",  "Volume as Volume2", "`Adj Close` as AdjClose2")
    df_res = df_temp1.join(df_temp2, ["Date"]).drop("Date").drop("company_name")
    return df_res

def corr_dfs(df1, df2):
    df_concat = concat_dfs(df1, df2)
    columns = df_concat.columns
    for i in range(len(columns) // 2):
        print(columns[i] + " & "+ columns[i + 6] + " : " + str(df_concat.corr(columns[i], columns[i + 6])))

def corr_dfs_execution(list_df, list_name):
    for i in range(len(list_df)):
        for j in range(i+1, len(list_df)):
            print(f"\nCorrelation between {list_name[i]} & {list_name[j]}:")
            corr_dfs(list_df[i], list_df[j])

# %% [markdown]
# # Rate of return
#
# ## Rate of return given `start_date` and `end_date`
#
# - Select the column and the `company_name` given the time frame
# - Find the first and the last record of the filtered dataframe
# - Apply the `rate of return` formula to the value `(last - first) / first`
# - Return as a Tuple containing the `rate of return` and `company_name`
#
# ## Best rate of return given `start_date` and a Period dataclass
#
# - `Period` class containing quantity of time to be added (`week, month, year`)
# - Find the `end_date` from the given `Period` dataclass
# - Loop through each column in the `df`:
#     - Loop through each stock in the `list_df`:
#         - Comparing the maximum `rate of return` using the `rate_of_return()` function
#     - Print out the maximum rate of return of a given period on each column

# %%
import datetime
from dateutil.relativedelta import relativedelta
from dataclasses import dataclass

@dataclass
class Period:
    week: int = 0
    month: int = 0
    year: int = 0

def rate_of_return(df, start_date, end_date, col):
    time_range = df.select(df[col],df['company_name']).where(df.Date >= start_date).where(df.Date <= end_date)
    if (time_range.count() > 0):
        first_record = time_range.collect()[0]
        last_record = time_range.collect()[-1]
        rate_of_return = (last_record[col] - first_record[col])/first_record[col] * 100
        return (rate_of_return, first_record['company_name'])
    return (float("-inf"), 'No Company')

def best_rate_of_return(list_df, start_date, period: Period):
    cols = ['Open', 'Close', 'High', 'Low', 'Adj close']
    end_date = start_date + relativedelta(months=period.month, weeks=period.week, years=period.year)
    print(f"Period between {start_date} - {end_date}")
    for col in cols:
        maxi = (float("-inf"), 'No Company')
        for df in list_df:
            rate = rate_of_return(df, start_date, end_date, col)
            maxi = rate if max(maxi[0], rate[0]) == rate[0] else maxi
        print(f"Max rate of return on {col}: {maxi[0]} - {maxi[1]}")

# %%
def list_df_calculation():
    amazon_path = "stocks_data/AMAZON.csv"
    apple_path = "stocks_data/APPLE.csv"
    facebook_path = "stocks_data/FACEBOOK.csv"
    google_path = "stocks_data/GOOGLE.csv"
    microsoft_path = "stocks_data/MICROSOFT.csv"
    tesla_path = "stocks_data/TESLA.csv"
    zoom_path = "stocks_data/ZOOM.csv"
    print("EXPLORATION")
    print("Amazon: \n ---------")
    amazon = read_disp_info(amazon_path)
    print("Apple:  \n ---------")
    apple = read_disp_info(apple_path)
    print("Facebook:  \n ---------")
    facebook = read_disp_info(facebook_path)
    print("Google: \n ---------")
    google = read_disp_info(google_path)
    print("Microsoft: \n ---------")
    microsoft = read_disp_info(microsoft_path)
    print("Tesla: \n ---------")
    tesla = read_disp_info(tesla_path)
    print("Zoom: \n ---------")
    zoom = read_disp_info(zoom_path)
    return [amazon, apple, facebook, google, microsoft, tesla, zoom]
    
def main_output():
    list_df = list_df_calculation()
    list_name = ['amazon', 'apple', 'facebook', 'google', 'microsoft', 'tesla', 'zoom']
    print("DESCRIBING")
    dfs_execution(list_df, list_name, describe_df)
    print("COUNT MISSING")
    dfs_execution(list_df, list_name, count_missing_alt)
    print("CORRELATION")
    dfs_execution(list_df, list_name, correlation)
    print("AVERAGE OPENNING AND CLOSING")
    dfs_execution(list_df, list_name, avg_open_close_wrapper)
    print("STOCK PRICES DAY TO DAY CHANGE")
    dfs_execution(list_df, list_name, stock_prices_day_to_day_change)
    print("STOCK PRICES MONTH TO MONTH CHANGE")
    dfs_execution(list_df, list_name, stock_prices_delta_monthly)
    print("DAILY RETURN")
    list_exec_dfs = dfs_execution(list_df, list_name, daily_return)
    print("HIGHEST DAILY RETURN (25 days)")
    highest_daily_return_df = highest_daily_return(list_exec_dfs, 25)
    highest_daily_return_df.show(n=10)
    print("AVERAGE DAILY RETURN (YEAR)")
    dfs_execution(list_exec_dfs, list_name, avg_daily_return_year)
    print("AVERAGE DAILY RETURN (MONTH)")
    dfs_execution(list_exec_dfs, list_name, avg_daily_return_month)
    print("AVERAGE DAILY RETURN (WEEK)")
    dfs_execution(list_exec_dfs, list_name, avg_daily_return_week)
    print("MOVING AVERAGE (5 data points)")
    dfs_execution(list_df, list_name, moving_average_wrapper)
    print("CORRELATION BETWEEN DIFFERENT STOCKS")
    corr_dfs_execution(list_df, list_name)
    print('')
    print("RATE OF RETURN (AMAZON) FROM 03-01-2017 TO 21-01-2017")
    rate = rate_of_return(list_df[0], datetime.datetime(2017, 1, 3), datetime.datetime(2017, 1, 21), 'Open')
    print(rate)
    print("BEST RATE OF RETURN (ALL STOCKS) FROM 07-01-2017 TO A PERIOD OF 1 YEAR 4 WEEKS ")
    best_rate_of_return(list_df, datetime.datetime(2017, 1, 7), Period(year=1, month=0, week=4))

main_output()
# Out:
# EXPLORATION
# Amazon:
#  ---------
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=758.760009765625, Low=747.7000122070312, Open=757.9199829101562, Close=753.6699829101562, Volume=3521100, Adj Close=753.6699829101562, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=759.6799926757812, Low=754.2000122070312, Open=758.3900146484375, Close=757.1799926757812, Volume=2510500, Adj Close=757.1799926757812, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=782.4000244140625, Low=760.260009765625, Open=761.5499877929688, Close=780.4500122070312, Volume=5830100, Adj Close=780.4500122070312, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=799.4400024414062, Low=778.47998046875, Open=782.3599853515625, Close=795.989990234375, Volume=5986200, Adj Close=795.989990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=801.77001953125, Low=791.77001953125, Open=798.0, Close=796.9199829101562, Volume=3446100, Adj Close=796.9199829101562, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=798.0, Low=789.5399780273438, Open=796.5999755859375, Close=795.9000244140625, Volume=2558400, Adj Close=795.9000244140625, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=799.5, Low=789.510009765625, Open=793.6599731445312, Close=799.02001953125, Volume=2992800, Adj Close=799.02001953125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=814.1300048828125, Low=799.5, Open=800.3099975585938, Close=813.6400146484375, Volume=4873900, Adj Close=813.6400146484375, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=821.6500244140625, Low=811.4000244140625, Open=814.3200073242188, Close=817.1400146484375, Volume=3791900, Adj Close=817.1400146484375, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=816.0, Low=803.4400024414062, Open=815.7000122070312, Close=809.719970703125, Volume=3670500, Adj Close=809.719970703125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=811.72998046875, Low=804.27001953125, Open=809.5, Close=807.47998046875, Volume=2354200, Adj Close=807.47998046875, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=813.510009765625, Low=807.3200073242188, Open=810.0, Close=809.0399780273438, Volume=2540800, Adj Close=809.0399780273438, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=816.02001953125, Low=806.260009765625, Open=815.280029296875, Close=808.3300170898438, Volume=3376200, Adj Close=808.3300170898438, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=818.5, Low=805.0800170898438, Open=806.7999877929688, Close=817.8800048828125, Volume=2797500, Adj Close=817.8800048828125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=823.989990234375, Low=814.5, Open=822.0, Close=822.4400024414062, Volume=2971700, Adj Close=822.4400024414062, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=837.4199829101562, Low=825.2899780273438, Open=825.7899780273438, Close=836.52001953125, Volume=3922600, Adj Close=836.52001953125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=843.8400268554688, Low=833.0, Open=835.530029296875, Close=839.1500244140625, Volume=3586300, Adj Close=839.1500244140625, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=839.7000122070312, Low=829.4400024414062, Open=839.0, Close=835.77001953125, Volume=2998700, Adj Close=835.77001953125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=833.5, Low=816.3800048828125, Open=833.0, Close=830.3800048828125, Volume=3747300, Adj Close=830.3800048828125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 31, 0, 0), High=826.989990234375, Low=819.5599975585938, Open=823.75, Close=823.47998046875, Volume=3137200, Adj Close=823.47998046875, company_name ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=3200.0, Low=3132.389892578125, Open=3135.0, Close=3195.68994140625, Volume=4309400, Adj Close=3195.68994140625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=3233.2900390625, Low=3174.989990234375, Open=3224.989990234375, Close=3190.550048828125, Volume=3174100, Adj Close=3190.550048828125, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=3288.989990234375, Low=3197.830078125, Open=3210.0, Close=3286.64990234375, Volume=4907900, Adj Close=3286.64990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=3496.239990234375, Low=3339.550048828125, Open=3349.93994140625, Close=3442.929931640625, Volume=8364200, Adj Close=3442.929931640625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=3492.3798828125, Low=3424.219970703125, Open=3467.989990234375, Close=3443.6298828125, Volume=5744700, Adj Close=3443.6298828125, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=3464.8798828125, Low=3340.0, Open=3447.0, Close=3363.7099609375, Volume=5828900, Adj Close=3363.7099609375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=3355.8798828125, Low=3280.0, Open=3292.010009765625, Close=3338.64990234375, Volume=5223400, Adj Close=3338.64990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=3399.659912109375, Low=3160.0, Open=3363.22998046875, Close=3272.7099609375, Volume=6474400, Adj Close=3272.7099609375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=3329.0, Low=3192.739990234375, Open=3299.610107421875, Close=3207.2099609375, Volume=5223600, Adj Close=3207.2099609375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=3266.0, Low=3192.010009765625, Open=3222.280029296875, Close=3217.010009765625, Volume=4509700, Adj Close=3217.010009765625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=3233.8798828125, Low=3160.0, Open=3212.5, Close=3184.93994140625, Volume=4592700, Adj Close=3184.93994140625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=3198.75, Low=3121.93994140625, Open=3189.8701171875, Close=3176.39990234375, Volume=4212000, Adj Close=3176.39990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=3205.330078125, Low=3140.0, Open=3191.0, Close=3204.39990234375, Volume=3466700, Adj Close=3204.39990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=3282.97998046875, Low=3153.300048828125, Open=3198.739990234375, Close=3207.0400390625, Volume=5901200, Adj Close=3207.0400390625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=3291.659912109375, Low=3211.300048828125, Open=3224.93994140625, Close=3286.330078125, Volume=4291000, Adj Close=3286.330078125, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=3264.02001953125, Low=3162.469970703125, Open=3249.300048828125, Close=3162.780029296875, Volume=5588300, Adj Close=3162.780029296875, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=3257.25, Low=3164.0, Open=3201.27001953125, Close=3211.010009765625, Volume=6596500, Adj Close=3211.010009765625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=3167.0, Low=3019.0, Open=3157.75, Close=3036.14990234375, Volume=8386400, Adj Close=3036.14990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=3079.7099609375, Low=2950.1201171875, Open=3061.739990234375, Close=3004.47998046875, Volume=7257400, Adj Close=3004.47998046875, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 11, 3, 0, 0), High=3074.89990234375, Low=2980.97998046875, Open=3018.530029296875, Close=3048.409912109375, Volume=4897900, Adj Close=3048.409912109375, company_name='AMAZON'), Row(Date=datetime.datet ...
# 987
# Apple:
#  ---------
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=29.082500457763672, Low=28.690000534057617, Open=28.950000762939453, Close=29.037500381469727, Volume=None, Adj Close=27.277639389038086, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=29.127500534057617, Low=28.9375, Open=28.962499618530273, Close=29.0049991607666, Volume=None, Adj Close=27.247108459472656, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=29.21500015258789, Low=28.952499389648438, Open=28.979999542236328, Close=29.15250015258789, Volume=None, Adj Close=27.38566780090332, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=29.540000915527344, Low=29.11750030517578, Open=29.19499969482422, Close=29.477500915527344, Volume=None, Adj Close=27.69097137451172, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=29.857500076293945, Low=29.485000610351562, Open=29.487499237060547, Close=29.747499465942383, Volume=None, Adj Close=27.944602966308594, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=29.844999313354492, Low=29.575000762939453, Open=29.6924991607666, Close=29.77750015258789, Volume=None, Adj Close=27.97278594970703, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=29.982500076293945, Low=29.649999618530273, Open=29.684999465942383, Close=29.9375, Volume=None, Adj Close=28.123088836669922, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=29.825000762939453, Low=29.552499771118164, Open=29.725000381469727, Close=29.8125, Volume=None, Adj Close=28.005664825439453, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=29.905000686645508, Low=29.702499389648438, Open=29.77750015258789, Close=29.760000228881836, Volume=None, Adj Close=27.956350326538086, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=30.059999465942383, Low=29.55500030517578, Open=29.584999084472656, Close=30.0, Volume=None, Adj Close=28.181800842285156, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=30.125, Low=29.927499771118164, Open=30.0, Close=29.997499465942383, Volume=None, Adj Close=28.17945671081543, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=30.022499084472656, Low=29.842500686645508, Open=29.850000381469727, Close=29.94499969482422, Volume=None, Adj Close=28.1301326751709, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=30.112499237060547, Low=29.9325008392334, Open=30.112499237060547, Close=30.0, Volume=None, Adj Close=28.181800842285156, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=30.202499389648438, Low=29.9424991607666, Open=30.0, Close=30.020000457763672, Volume=None, Adj Close=28.200590133666992, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=30.024999618530273, Low=29.875, Open=29.887500762939453, Close=29.99250030517578, Volume=None, Adj Close=28.17475700378418, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=30.524999618530273, Low=30.06999969482422, Open=30.104999542236328, Close=30.469999313354492, Volume=None, Adj Close=28.623313903808594, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=30.610000610351562, Low=30.399999618530273, Open=30.417499542236328, Close=30.485000610351562, Volume=None, Adj Close=28.637407302856445, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=30.587499618530273, Low=30.399999618530273, Open=30.53499984741211, Close=30.487499237060547, Volume=None, Adj Close=28.639755249023438, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=30.407499313354492, Low=30.165000915527344, Open=30.232500076293945, Close=30.407499313354492, Volume=None, Adj Close=28.564605712890625, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 31, 0, 0), High=30.34749984741211, Low=30.155000686645508, O ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=115.55000305175781, Low=114.12999725341797, Open=114.62000274658203, Close=115.08000183105469, Volume=None, Adj Close=114.88180541992188, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=116.4000015258789, Low=114.58999633789062, Open=116.25, Close=114.97000122070312, Volume=None, Adj Close=114.77198791503906, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=117.0, Low=114.91999816894531, Open=115.27999877929688, Close=116.97000122070312, Volume=None, Adj Close=116.76854705810547, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=125.18000030517578, Low=119.27999877929688, Open=120.05999755859375, Close=124.4000015258789, Volume=None, Adj Close=124.18575286865234, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=125.38999938964844, Low=119.6500015258789, Open=125.2699966430664, Close=121.0999984741211, Volume=None, Adj Close=120.89143371582031, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=123.02999877929688, Low=119.62000274658203, Open=121.0, Close=121.19000244140625, Volume=None, Adj Close=120.98127746582031, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=121.19999694824219, Low=118.1500015258789, Open=118.72000122070312, Close=120.70999908447266, Volume=None, Adj Close=120.50210571289062, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=121.55000305175781, Low=118.80999755859375, Open=121.27999877929688, Close=119.0199966430664, Volume=None, Adj Close=118.81501007080078, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=120.41999816894531, Low=115.66000366210938, Open=119.95999908447266, Close=115.9800033569336, Volume=None, Adj Close=115.7802505493164, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=118.9800033569336, Low=115.62999725341797, Open=116.19999694824219, Close=117.51000213623047, Volume=None, Adj Close=117.3076171875, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=118.70999908447266, Low=116.44999694824219, Open=116.66999816894531, Close=116.87000274658203, Volume=None, Adj Close=116.6687240600586, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=118.04000091552734, Low=114.58999633789062, Open=117.44999694824219, Close=115.75, Volume=None, Adj Close=115.55064392089844, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=116.55000305175781, Low=114.27999877929688, Open=116.38999938964844, Close=115.04000091552734, Volume=None, Adj Close=114.84187316894531, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=116.55000305175781, Low=112.87999725341797, Open=114.01000213623047, Close=115.05000305175781, Volume=None, Adj Close=114.85185241699219, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=117.27999877929688, Low=114.54000091552734, Open=115.48999786376953, Close=116.5999984741211, Volume=None, Adj Close=116.39917755126953, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=115.43000030517578, Low=111.0999984741211, Open=115.05000305175781, Close=111.19999694824219, Volume=None, Adj Close=111.00847625732422, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=116.93000030517578, Low=112.19999694824219, Open=112.37000274658203, Close=115.31999969482422, Volume=None, Adj Close=115.12138366699219, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=111.98999786376953, Low=107.72000122070312, Open=111.05999755859375, Close=108.86000061035156, Volume=None, Adj Close=108.67251586914062, company_name='APPLE'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=110.68000030517578, Low=107.31999969482422, Open=109.11000061035156, Close=108.7699966430664, Volume=None, Adj Close=108.5826644897461, company_name='APPLE'), Row(Da ...
# 987
# Facebook:
#  ---------
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=117.83999633789062, Low=115.51000213623047, Open=116.02999877929688, Close=116.86000061035156, Volume=20663900, Adj Close=116.86000061035156, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=119.66000366210938, Low=117.29000091552734, Open=117.55000305175781, Close=118.69000244140625, Volume=19630900, Adj Close=118.69000244140625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=120.94999694824219, Low=118.31999969482422, Open=118.86000061035156, Close=120.66999816894531, Volume=19492200, Adj Close=120.66999816894531, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=123.87999725341797, Low=120.02999877929688, Open=120.9800033569336, Close=123.41000366210938, Volume=28545300, Adj Close=123.41000366210938, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=125.43000030517578, Low=123.04000091552734, Open=123.55000305175781, Close=124.9000015258789, Volume=22880400, Adj Close=124.9000015258789, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=125.5, Low=124.27999877929688, Open=124.81999969482422, Close=124.3499984741211, Volume=17324600, Adj Close=124.3499984741211, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=126.12000274658203, Low=124.05999755859375, Open=124.3499984741211, Close=126.08999633789062, Volume=18356500, Adj Close=126.08999633789062, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=126.7300033569336, Low=124.80000305175781, Open=125.61000061035156, Close=126.62000274658203, Volume=18653900, Adj Close=126.62000274658203, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=129.27000427246094, Low=127.37000274658203, Open=127.48999786376953, Close=128.33999633789062, Volume=24884300, Adj Close=128.33999633789062, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=128.33999633789062, Low=127.4000015258789, Open=128.0399932861328, Close=127.87000274658203, Volume=15294500, Adj Close=127.87000274658203, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=128.42999267578125, Low=126.83999633789062, Open=128.41000366210938, Close=127.91999816894531, Volume=13145900, Adj Close=127.91999816894531, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=128.35000610351562, Low=127.44999694824219, Open=128.22999572753906, Close=127.55000305175781, Volume=12195500, Adj Close=127.55000305175781, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=128.47999572753906, Low=126.77999877929688, Open=128.10000610351562, Close=127.04000091552734, Volume=19097200, Adj Close=127.04000091552734, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=129.25, Low=126.94999694824219, Open=127.30999755859375, Close=128.92999267578125, Volume=16593600, Adj Close=128.92999267578125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=129.89999389648438, Low=128.3800048828125, Open=129.3800048828125, Close=129.3699951171875, Volume=15162700, Adj Close=129.3699951171875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=131.74000549316406, Low=129.77000427246094, Open=130.0, Close=131.47999572753906, Volume=18731300, Adj Close=131.47999572753906, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=133.13999938964844, Low=131.44000244140625, Open=131.6300048828125, Close=132.77999877929688, Volume=20020100, Adj Close=132.77999877929688, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=132.9499969482422, Low=131.0800018310547, Open=132.67999267578125, Close=132.17999267578125, Volume=19539500, Adj Close=132.17999267578125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=131.5800018310547, Low=129.60000610351562, Ope ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=260.17999267578125, Low=254.82000732421875, Open=259.2099914550781, Close=258.1199951171875, Volume=23133400, Adj Close=258.1199951171875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=264.6199951171875, Low=259.1499938964844, Open=259.75, Close=263.760009765625, Volume=16312800, Adj Close=263.760009765625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=264.75, Low=262.1700134277344, Open=264.5199890136719, Close=264.45001220703125, Volume=14107800, Adj Close=264.45001220703125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=280.17999267578125, Low=267.8699951171875, Open=270.20001220703125, Close=275.75, Volume=31019300, Adj Close=275.75, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=279.1000061035156, Low=273.3900146484375, Open=277.5799865722656, Close=276.1400146484375, Volume=18063300, Adj Close=276.1400146484375, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=278.75, Low=271.5, Open=277.6199951171875, Close=271.82000732421875, Volume=15601200, Adj Close=271.82000732421875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=269.0400085449219, Low=263.6700134277344, Open=267.6000061035156, Close=266.7200012207031, Volume=15416100, Adj Close=266.7200012207031, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=271.3699951171875, Low=265.29998779296875, Open=267.3800048828125, Close=265.92999267578125, Volume=16622700, Adj Close=265.92999267578125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=268.54998779296875, Low=259.8800048828125, Open=265.5299987792969, Close=261.3999938964844, Volume=13587000, Adj Close=261.3999938964844, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=269.70001220703125, Low=262.8800048828125, Open=263.05999755859375, Close=267.55999755859375, Volume=18763200, Adj Close=267.55999755859375, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=283.04998779296875, Low=276.3699951171875, Open=279.55999755859375, Close=278.7300109863281, Volume=28998600, Adj Close=278.7300109863281, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=282.45001220703125, Low=275.0400085449219, Open=279.8699951171875, Close=278.1199951171875, Volume=16720000, Adj Close=278.1199951171875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=285.239990234375, Low=276.82000732421875, Open=278.79998779296875, Close=284.7900085449219, Volume=17535200, Adj Close=284.7900085449219, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=285.2300109863281, Low=274.260009765625, Open=283.1600036621094, Close=277.1099853515625, Volume=21322900, Adj Close=277.1099853515625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=284.510009765625, Low=276.30999755859375, Open=278.760009765625, Close=283.2900085449219, Volume=16287200, Adj Close=283.2900085449219, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=278.7900085449219, Low=267.260009765625, Open=278.7900085449219, Close=267.6700134277344, Volume=23121800, Adj Close=267.6700134277344, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=283.6000061035156, Low=273.7799987792969, Open=276.54998779296875, Close=280.8299865722656, Volume=32368100, Adj Close=280.8299865722656, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=276.70001220703125, Low=259.1000061035156, Open=274.5, Close=263.1099853515625, Volume=47247800, Adj Close=263.1099853515625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=270.4700012207031, Low=257.3399963378906, Open=264.6000061035156, Close=261.3599853515625, Volume=27165700, Adj Close=261.35 ...
# 987
# Google:
#  ---------
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=789.6300048828125, Low=775.7999877929688, Open=778.8099975585938, Close=786.1400146484375, Volume=1657300, Adj Close=786.1400146484375, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=791.3400268554688, Low=783.1599731445312, Open=788.3599853515625, Close=786.9000244140625, Volume=1073000, Adj Close=786.9000244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=794.47998046875, Low=785.02001953125, Open=786.0800170898438, Close=794.02001953125, Volume=1335200, Adj Close=794.02001953125, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=807.9000244140625, Low=792.2039794921875, Open=795.260009765625, Close=806.1500244140625, Volume=1640200, Adj Close=806.1500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=809.9660034179688, Low=802.8300170898438, Open=806.4000244140625, Close=806.6500244140625, Volume=1274600, Adj Close=806.6500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=809.1300048828125, Low=803.510009765625, Open=807.8599853515625, Close=804.7899780273438, Volume=1176800, Adj Close=804.7899780273438, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=808.1500244140625, Low=801.3699951171875, Open=805.0, Close=807.9099731445312, Volume=1065900, Adj Close=807.9099731445312, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=807.3900146484375, Low=799.1699829101562, Open=807.1400146484375, Close=806.3599853515625, Volume=1353100, Adj Close=806.3599853515625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=811.2239990234375, Low=806.6900024414062, Open=807.47998046875, Close=807.8800048828125, Volume=1099200, Adj Close=807.8800048828125, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=807.1400146484375, Low=800.3699951171875, Open=807.0800170898438, Close=804.6099853515625, Volume=1362100, Adj Close=804.6099853515625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=806.2050170898438, Low=800.989990234375, Open=805.8099975585938, Close=806.0700073242188, Volume=1294400, Adj Close=806.0700073242188, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=809.47998046875, Low=801.7999877929688, Open=805.1199951171875, Close=802.1749877929688, Volume=919300, Adj Close=802.1749877929688, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=806.9099731445312, Low=801.6900024414062, Open=806.9099731445312, Close=805.02001953125, Volume=1670000, Adj Close=805.02001953125, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=820.8699951171875, Low=803.739990234375, Open=807.25, Close=819.3099975585938, Volume=1963600, Adj Close=819.3099975585938, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=825.9000244140625, Low=817.8209838867188, Open=822.2999877929688, Close=823.8699951171875, Volume=1474000, Adj Close=823.8699951171875, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=835.77001953125, Low=825.0599975585938, Open=829.6199951171875, Close=835.6699829101562, Volume=1494500, Adj Close=835.6699829101562, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=838.0, Low=827.010009765625, Open=837.8099975585938, Close=832.1500244140625, Volume=2973900, Adj Close=832.1500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=841.9500122070312, Low=820.4400024414062, Open=834.7100219726562, Close=823.3099975585938, Volume=2965800, Adj Close=823.3099975585938, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=815.8400268554688, Low=799.7999877929688, Open=814.6599731445312, Close=802.3200073242188, Volume=3246600, Adj Close=802.3200073242188, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=1468.9599609375, Low=1436.0, Open=1464.2900390625, Close=1460.2900390625, Volume=1746200, Adj Close=1460.2900390625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=1490.0, Low=1465.0899658203125, Open=1465.0899658203125, Close=1485.9300537109375, Volume=1187800, Adj Close=1485.9300537109375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=1516.52001953125, Low=1489.449951171875, Open=1494.699951171875, Close=1515.219970703125, Volume=1435300, Adj Close=1515.219970703125, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=1593.8599853515625, Low=1532.5699462890625, Open=1543.0, Close=1569.1500244140625, Volume=2482600, Adj Close=1569.1500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=1590.0, Low=1563.199951171875, Open=1583.72998046875, Close=1571.6800537109375, Volume=1601000, Adj Close=1571.6800537109375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=1587.6839599609375, Low=1550.530029296875, Open=1578.5899658203125, Close=1568.0799560546875, Volume=1931000, Adj Close=1568.0799560546875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=1575.10498046875, Low=1545.030029296875, Open=1547.1500244140625, Close=1559.1300048828125, Volume=1540000, Adj Close=1559.1300048828125, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=1581.1300048828125, Low=1563.0, Open=1565.8499755859375, Close=1573.010009765625, Volume=1434700, Adj Close=1573.010009765625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=1588.1500244140625, Low=1528.0, Open=1580.4599609375, Close=1534.6099853515625, Volume=1607100, Adj Close=1534.6099853515625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=1577.5, Low=1525.6700439453125, Open=1527.050048828125, Close=1555.9300537109375, Volume=2241700, Adj Close=1555.9300537109375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=1618.72998046875, Low=1571.6300048828125, Open=1573.3299560546875, Close=1593.31005859375, Volume=2568300, Adj Close=1593.31005859375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=1621.989990234375, Low=1585.0, Open=1593.050048828125, Close=1615.3299560546875, Volume=1433600, Adj Close=1615.3299560546875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=1642.3599853515625, Low=1620.510009765625, Open=1626.0699462890625, Close=1641.0, Volume=1375800, Adj Close=1641.0, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=1638.239990234375, Low=1576.5, Open=1625.010009765625, Close=1590.449951171875, Volume=1853300, Adj Close=1590.449951171875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=1606.844970703125, Low=1582.780029296875, Open=1595.6700439453125, Close=1604.260009765625, Volume=1229000, Adj Close=1604.260009765625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=1561.3499755859375, Low=1514.6199951171875, Open=1559.739990234375, Close=1516.6199951171875, Volume=1834000, Adj Close=1516.6199951171875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=1593.7099609375, Low=1522.239990234375, Open=1522.3599853515625, Close=1567.239990234375, Volume=2003100, Adj Close=1567.239990234375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=1687.0, Low=1604.4599609375, Open=1672.1099853515625, Close=1621.010009765625, Volume=4329100, Adj Close=1621.010009765625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=1660.77001953125, Low=1616.030029296875, Open=1628.1600341796875, Close=1626.030029296875, Volume=2535400, Adj Close=1626.030029296875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 11, 3, 0, 0), High=1661.699951171875, ...
# 987
# Microsoft:
#  ---------
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=62.84000015258789, Low=62.130001068115234, Open=62.790000915527344, Close=62.58000183105469, Volume=None, Adj Close=58.67324447631836, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=62.75, Low=62.119998931884766, Open=62.47999954223633, Close=62.29999923706055, Volume=None, Adj Close=58.41072463989258, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=62.65999984741211, Low=62.029998779296875, Open=62.189998626708984, Close=62.29999923706055, Volume=None, Adj Close=58.41072463989258, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=63.150001525878906, Low=62.040000915527344, Open=62.29999923706055, Close=62.84000015258789, Volume=None, Adj Close=58.917015075683594, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=63.08000183105469, Low=62.540000915527344, Open=62.7599983215332, Close=62.63999938964844, Volume=None, Adj Close=58.729496002197266, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=63.06999969482422, Low=62.279998779296875, Open=62.72999954223633, Close=62.619998931884766, Volume=None, Adj Close=58.71074676513672, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=63.22999954223633, Low=62.43000030517578, Open=62.61000061035156, Close=63.189998626708984, Volume=None, Adj Close=59.24515914916992, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=63.400001525878906, Low=61.95000076293945, Open=63.060001373291016, Close=62.61000061035156, Volume=None, Adj Close=58.70137023925781, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=62.869998931884766, Low=62.349998474121094, Open=62.619998931884766, Close=62.70000076293945, Volume=None, Adj Close=58.7857551574707, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=62.70000076293945, Low=62.029998779296875, Open=62.68000030517578, Close=62.529998779296875, Volume=None, Adj Close=58.62636947631836, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=62.70000076293945, Low=62.119998931884766, Open=62.66999816894531, Close=62.5, Volume=None, Adj Close=58.59824752807617, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=62.97999954223633, Low=62.20000076293945, Open=62.2400016784668, Close=62.29999923706055, Volume=None, Adj Close=58.41072463989258, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=62.81999969482422, Low=62.369998931884766, Open=62.66999816894531, Close=62.7400016784668, Volume=None, Adj Close=58.82326126098633, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=63.119998931884766, Low=62.56999969482422, Open=62.70000076293945, Close=62.959999084472656, Volume=None, Adj Close=59.02952575683594, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=63.7400016784668, Low=62.939998626708984, Open=63.20000076293945, Close=63.52000045776367, Volume=None, Adj Close=59.554569244384766, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=64.0999984741211, Low=63.45000076293945, Open=63.95000076293945, Close=63.68000030517578, Volume=None, Adj Close=59.70457458496094, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=64.54000091552734, Low=63.54999923706055, Open=64.12000274658203, Close=64.2699966430664, Volume=None, Adj Close=60.25773620605469, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=65.91000366210938, Low=64.88999938964844, Open=65.38999938964844, Close=65.77999877929688, Volume=None, Adj Close=61.67348098754883, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=65.79000091552734, Low=64.80000305175781, Open=65.69000244140625, Close=65.12999725341797, Volume=None, Adj Close=61.06404495239258, company_n ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=210.11000061035156, Low=206.72000122070312, Open=207.05999755859375, Close=209.8300018310547, Volume=None, Adj Close=209.28208923339844, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=211.19000244140625, Low=208.32000732421875, Open=210.50999450683594, Close=210.5800018310547, Volume=None, Adj Close=210.03013610839844, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=215.86000061035156, Low=211.22999572753906, Open=211.22999572753906, Close=215.80999755859375, Volume=None, Adj Close=215.24647521972656, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=223.86000061035156, Low=216.80999755859375, Open=218.7899932861328, Close=221.39999389648438, Volume=None, Adj Close=220.82186889648438, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=225.2100067138672, Low=220.42999267578125, Open=222.72000122070312, Close=222.86000061035156, Volume=None, Adj Close=222.27806091308594, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=224.22000122070312, Low=219.1300048828125, Open=223.0, Close=220.86000061035156, Volume=None, Adj Close=220.2832794189453, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=220.36000061035156, Low=216.00999450683594, Open=217.10000610351562, Close=219.66000366210938, Volume=None, Adj Close=219.08642578125, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=222.2899932861328, Low=219.32000732421875, Open=220.14999389648438, Close=219.66000366210938, Volume=None, Adj Close=219.08642578125, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=222.3000030517578, Low=213.72000122070312, Open=220.4199981689453, Close=214.22000122070312, Volume=None, Adj Close=213.66062927246094, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=217.3699951171875, Low=213.08999633789062, Open=215.8000030517578, Close=214.64999389648438, Volume=None, Adj Close=214.08949279785156, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=216.9199981689453, Low=213.1199951171875, Open=213.1199951171875, Close=214.8000030517578, Volume=None, Adj Close=214.23912048339844, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=216.05999755859375, Low=211.6999969482422, Open=213.92999267578125, Close=214.88999938964844, Volume=None, Adj Close=214.32887268066406, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=216.27999877929688, Low=213.16000366210938, Open=215.02999877929688, Close=216.22999572753906, Volume=None, Adj Close=215.66537475585938, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=216.33999633789062, Low=208.10000610351562, Open=213.85000610351562, Close=210.0800018310547, Volume=None, Adj Close=209.53143310546875, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=214.6699981689453, Low=210.3300018310547, Open=211.58999633789062, Close=213.25, Volume=None, Adj Close=212.6931610107422, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=208.83999633789062, Low=202.10000610351562, Open=207.6699981689453, Close=202.67999267578125, Volume=None, Adj Close=202.1507568359375, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=207.36000061035156, Low=203.3699951171875, Open=204.07000732421875, Close=204.72000122070312, Volume=None, Adj Close=204.1854248046875, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=204.2899932861328, Low=199.6199951171875, Open=203.5, Close=202.47000122070312, Volume=None, Adj Close=201.94131469726562, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=205.27999877929688, Low=200.1199951171875, Open=204.2899932861328, Close=202.3300018310547, Volu ...
# 987
# Tesla:
#  ---------
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=44.066001892089844, Low=42.19200134277344, Open=42.97200012207031, Close=43.39799880981445, Volume=None, Adj Close=43.39799880981445, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=45.599998474121094, Low=42.86199951171875, Open=42.95000076293945, Close=45.39799880981445, Volume=None, Adj Close=45.39799880981445, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=45.49599838256836, Low=44.38999938964844, Open=45.284000396728516, Close=45.349998474121094, Volume=None, Adj Close=45.349998474121094, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=46.0620002746582, Low=45.09000015258789, Open=45.38600158691406, Close=45.801998138427734, Volume=None, Adj Close=45.801998138427734, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=46.38399887084961, Low=45.599998474121094, Open=45.79399871826172, Close=46.25600051879883, Volume=None, Adj Close=46.25600051879883, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=46.400001525878906, Low=45.37799835205078, Open=46.400001525878906, Close=45.9739990234375, Volume=None, Adj Close=45.9739990234375, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=45.99599838256836, Low=45.33599853515625, Open=45.81399917602539, Close=45.94599914550781, Volume=None, Adj Close=45.94599914550781, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=46.13999938964844, Low=45.11600112915039, Open=45.8120002746582, Close=45.917999267578125, Volume=None, Adj Close=45.917999267578125, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=47.56999969482422, Low=45.917999267578125, Open=46.0, Close=47.54999923706055, Volume=None, Adj Close=47.54999923706055, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=47.992000579833984, Low=46.874000549316406, Open=47.34000015258789, Close=47.11600112915039, Volume=None, Adj Close=47.11600112915039, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=47.94200134277344, Low=47.11600112915039, Open=47.33000183105469, Close=47.672000885009766, Volume=None, Adj Close=47.672000885009766, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=49.736000061035156, Low=48.150001525878906, Open=49.45000076293945, Close=48.75199890136719, Volume=None, Adj Close=48.75199890136719, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=49.20000076293945, Low=48.60200119018555, Open=49.09199905395508, Close=48.94599914550781, Volume=None, Adj Close=48.94599914550781, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=50.178001403808594, Low=49.099998474121094, Open=49.16999816894531, Close=49.784000396728516, Volume=None, Adj Close=49.784000396728516, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=50.959999084472656, Low=49.93000030517578, Open=50.0, Close=50.922000885009766, Volume=None, Adj Close=50.922000885009766, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=51.69200134277344, Low=50.36000061035156, Open=51.46200180053711, Close=50.89400100708008, Volume=None, Adj Close=50.89400100708008, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=51.14799880981445, Low=50.150001525878906, Open=50.858001708984375, Close=50.50199890136719, Volume=None, Adj Close=50.50199890136719, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=50.599998474121094, Low=49.70399856567383, Open=50.2760009765625, Close=50.59000015258789, Volume=None, Adj Close=50.59000015258789, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=51.05799865722656, Low=49.41999816894531, Open=50.50600051879883, Close=50.125999450683594, Volume=None, Adj Close=50.125999450683594, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 31, 0, 0), High= ...
# ...
# | -2.536000061035156| 03-05-2019|
# |-0.7959991455078125| 10-05-2019|
# | -2.308000183105469| 17-05-2019|
# | 3.1079986572265623| 24-05-2019|
# |-1.1099987030029297| 31-05-2019|
# | 0.6479995727539063| 07-06-2019|
# |-0.2399993896484375| 14-06-2019|
# +-------------------+-----------+
# only showing top 10 rows
#
#
# MOVING AVERAGE (5 data points)
# amazon
# +-------------------+------+------+------+------+-------+---------+------------+-----------------+
# |               Date|  High|   Low|  Open| Close| Volume|Adj Close|company_name|   moving_average|
# +-------------------+------+------+------+------+-------+---------+------------+-----------------+
# |2017-01-03 00:00:00|758.76| 747.7|757.92|753.67|3521100|   753.67|      AMAZON|757.9199829101562|
# |2017-01-04 00:00:00|759.68| 754.2|758.39|757.18|2510500|   757.18|      AMAZON|758.3900146484375|
# |2017-01-05 00:00:00| 782.4|760.26|761.55|780.45|5830100|   780.45|      AMAZON|761.5499877929688|
# |2017-01-06 00:00:00|799.44|778.48|782.36|795.99|5986200|   795.99|      AMAZON|782.3599853515625|
# |2017-01-09 00:00:00|801.77|791.77| 798.0|796.92|3446100|   796.92|      AMAZON|            798.0|
# |2017-01-10 00:00:00| 798.0|789.54| 796.6| 795.9|2558400|    795.9|      AMAZON|796.5999755859375|
# |2017-01-11 00:00:00| 799.5|789.51|793.66|799.02|2992800|   799.02|      AMAZON|793.6599731445312|
# |2017-01-12 00:00:00|814.13| 799.5|800.31|813.64|4873900|   813.64|      AMAZON|800.3099975585938|
# |2017-01-13 00:00:00|821.65| 811.4|814.32|817.14|3791900|   817.14|      AMAZON|814.3200073242188|
# |2017-01-17 00:00:00| 816.0|803.44| 815.7|809.72|3670500|   809.72|      AMAZON|815.7000122070312|
# +-------------------+------+------+------+------+-------+---------+------------+-----------------+
# only showing top 10 rows
#
#
# apple
# +-------------------+-------+-------+-------+-------+------+---------+------------+------------------+
# |               Date|   High|    Low|   Open|  Close|Volume|Adj Close|company_name|    moving_average|
# +-------------------+-------+-------+-------+-------+------+---------+------------+------------------+
# |2017-01-03 00:00:00|29.0825|  28.69|  28.95|29.0375|  null| 27.27764|       APPLE|28.950000762939453|
# |2017-01-04 00:00:00|29.1275|28.9375|28.9625| 29.005|  null|27.247108|       APPLE|28.962499618530273|
# |2017-01-05 00:00:00| 29.215|28.9525|  28.98|29.1525|  null|27.385668|       APPLE|28.979999542236328|
# |2017-01-06 00:00:00|  29.54|29.1175| 29.195|29.4775|  null|27.690971|       APPLE| 29.19499969482422|
# |2017-01-09 00:00:00|29.8575| 29.485|29.4875|29.7475|  null|27.944603|       APPLE|29.487499237060547|
# |2017-01-10 00:00:00| 29.845| 29.575|29.6925|29.7775|  null|27.972786|       APPLE|  29.6924991607666|
# |2017-01-11 00:00:00|29.9825|  29.65| 29.685|29.9375|  null|28.123089|       APPLE|29.684999465942383|
# |2017-01-12 00:00:00| 29.825|29.5525| 29.725|29.8125|  null|28.005665|       APPLE|29.725000381469727|
# |2017-01-13 00:00:00| 29.905|29.7025|29.7775|  29.76|  null| 27.95635|       APPLE| 29.77750015258789|
# |2017-01-17 00:00:00|  30.06| 29.555| 29.585|   30.0|  null|  28.1818|       APPLE|29.584999084472656|
# +-------------------+-------+-------+-------+-------+------+---------+------------+------------------+
# only showing top 10 rows
#
#
# facebook
# +-------------------+------+------+------+------+--------+---------+------------+------------------+
# |               Date|  High|   Low|  Open| Close|  Volume|Adj Close|company_name|    moving_average|
# +-------------------+------+------+------+------+--------+---------+------------+------------------+
# |2017-01-03 00:00:00|117.84|115.51|116.03|116.86|20663900|   116.86|    FACEBOOK|116.02999877929688|
# |2017-01-04 00:00:00|119.66|117.29|117.55|118.69|19630900|   118.69|    FACEBOOK|117.55000305175781|
# |2017-01-05 00:00:00|120.95|118.32|118.86|120.67|19492200|   120.67|    FACEBOOK|118.86000061035156|
# |2017-01-06 00:00:00|123.88|120.03|120.98|123.41|28545300|   123.41|    FACEBOOK| 120.9800033569336|
# |2017-01-09 00:00:00|125.43|123.04|123.55| 124.9|22880400|    124.9|    FACEBOOK|123.55000305175781|
# |2017-01-10 00:00:00| 125.5|124.28|124.82|124.35|17324600|   124.35|    FACEBOOK|124.81999969482422|
# |2017-01-11 00:00:00|126.12|124.06|124.35|126.09|18356500|   126.09|    FACEBOOK| 124.3499984741211|
# |2017-01-12 00:00:00|126.73| 124.8|125.61|126.62|18653900|   126.62|    FACEBOOK|125.61000061035156|
# |2017-01-13 00:00:00|129.27|127.37|127.49|128.34|24884300|   128.34|    FACEBOOK|127.48999786376953|
# |2017-01-17 00:00:00|128.34| 127.4|128.04|127.87|15294500|   127.87|    FACEBOOK| 128.0399932861328|
# +-------------------+------+------+------+------+--------+---------+------------+------------------+
# only showing top 10 rows
#
#
# google
# +-------------------+-------+-------+------+------+-------+---------+------------+-----------------+
# |               Date|   High|    Low|  Open| Close| Volume|Adj Close|company_name|   moving_average|
# +-------------------+-------+-------+------+------+-------+---------+------------+-----------------+
# |2017-01-03 00:00:00| 789.63|  775.8|778.81|786.14|1657300|   786.14|      GOOGLE|778.8099975585938|
# |2017-01-04 00:00:00| 791.34| 783.16|788.36| 786.9|1073000|    786.9|      GOOGLE|788.3599853515625|
# |2017-01-05 00:00:00| 794.48| 785.02|786.08|794.02|1335200|   794.02|      GOOGLE|786.0800170898438|
# |2017-01-06 00:00:00|  807.9|792.204|795.26|806.15|1640200|   806.15|      GOOGLE| 795.260009765625|
# |2017-01-09 00:00:00|809.966| 802.83| 806.4|806.65|1274600|   806.65|      GOOGLE|806.4000244140625|
# |2017-01-10 00:00:00| 809.13| 803.51|807.86|804.79|1176800|   804.79|      GOOGLE|807.8599853515625|
# |2017-01-11 00:00:00| 808.15| 801.37| 805.0|807.91|1065900|   807.91|      GOOGLE|            805.0|
# |2017-01-12 00:00:00| 807.39| 799.17|807.14|806.36|1353100|   806.36|      GOOGLE|807.1400146484375|
# |2017-01-13 00:00:00|811.224| 806.69|807.48|807.88|1099200|   807.88|      GOOGLE|  807.47998046875|
# |2017-01-17 00:00:00| 807.14| 800.37|807.08|804.61|1362100|   804.61|      GOOGLE|807.0800170898438|
# +-------------------+-------+-------+------+------+-------+---------+------------+-----------------+
# only showing top 10 rows
#
#
# microsoft
# +-------------------+-----+-----+-----+-----+------+---------+------------+------------------+
# |               Date| High|  Low| Open|Close|Volume|Adj Close|company_name|    moving_average|
# +-------------------+-----+-----+-----+-----+------+---------+------------+------------------+
# |2017-01-03 00:00:00|62.84|62.13|62.79|62.58|  null|58.673244|   MICROSOFT|62.790000915527344|
# |2017-01-04 00:00:00|62.75|62.12|62.48| 62.3|  null|58.410725|   MICROSOFT| 62.47999954223633|
# |2017-01-05 00:00:00|62.66|62.03|62.19| 62.3|  null|58.410725|   MICROSOFT|62.189998626708984|
# |2017-01-06 00:00:00|63.15|62.04| 62.3|62.84|  null|58.917015|   MICROSOFT| 62.29999923706055|
# |2017-01-09 00:00:00|63.08|62.54|62.76|62.64|  null|58.729496|   MICROSOFT|  62.7599983215332|
# |2017-01-10 00:00:00|63.07|62.28|62.73|62.62|  null|58.710747|   MICROSOFT| 62.72999954223633|
# |2017-01-11 00:00:00|63.23|62.43|62.61|63.19|  null| 59.24516|   MICROSOFT| 62.61000061035156|
# |2017-01-12 00:00:00| 63.4|61.95|63.06|62.61|  null| 58.70137|   MICROSOFT|63.060001373291016|
# |2017-01-13 00:00:00|62.87|62.35|62.62| 62.7|  null|58.785755|   MICROSOFT|62.619998931884766|
# |2017-01-17 00:00:00| 62.7|62.03|62.68|62.53|  null| 58.62637|   MICROSOFT| 62.68000030517578|
# +-------------------+-----+-----+-----+-----+------+---------+------------+------------------+
# only showing top 10 rows
#
#
# tesla
# +-------------------+------+------+------+------+------+---------+------------+------------------+
# |               Date|  High|   Low|  Open| Close|Volume|Adj Close|company_name|    moving_average|
# +-------------------+------+------+------+------+------+---------+------------+------------------+
# |2017-01-03 00:00:00|44.066|42.192|42.972|43.398|  null|   43.398|       TESLA| 42.97200012207031|
# |2017-01-04 00:00:00|  45.6|42.862| 42.95|45.398|  null|   45.398|       TESLA| 42.95000076293945|
# |2017-01-05 00:00:00|45.496| 44.39|45.284| 45.35|  null|    45.35|       TESLA|45.284000396728516|
# |2017-01-06 00:00:00|46.062| 45.09|45.386|45.802|  null|   45.802|       TESLA| 45.38600158691406|
# |2017-01-09 00:00:00|46.384|  45.6|45.794|46.256|  null|   46.256|       TESLA| 45.79399871826172|
# |2017-01-10 00:00:00|  46.4|45.378|  46.4|45.974|  null|   45.974|       TESLA|46.400001525878906|
# |2017-01-11 00:00:00|45.996|45.336|45.814|45.946|  null|   45.946|       TESLA| 45.81399917602539|
# |2017-01-12 00:00:00| 46.14|45.116|45.812|45.918|  null|   45.918|       TESLA|  45.8120002746582|
# |2017-01-13 00:00:00| 47.57|45.918|  46.0| 47.55|  null|    47.55|       TESLA|              46.0|
# |2017-01-17 00:00:00|47.992|46.874| 47.34|47.116|  null|   47.116|       TESLA| 47.34000015258789|
# +-------------------+------+------+------+------+------+---------+------------+------------------+
# only showing top 10 rows
#
#
# zoom
# +-------------------+------+------+-----+-----+--------+---------+------------+-----------------+
# |               Date|  High|   Low| Open|Close|  Volume|Adj Close|company_name|   moving_average|
# +-------------------+------+------+-----+-----+--------+---------+------------+-----------------+
# |2019-04-18 00:00:00|  66.0|60.321| 65.0| 62.0|25764700|     62.0|        ZOOM|             65.0|
# |2019-04-22 00:00:00|  68.9| 59.94| 61.0| 65.7| 9949700|     65.7|        ZOOM|             61.0|
# |2019-04-23 00:00:00|74.169| 65.55|66.87| 69.0| 6786500|     69.0|        ZOOM|66.87000274658203|
# |2019-04-24 00:00:00|  71.5| 63.16| 71.4| 63.2| 4973500|     63.2|        ZOOM| 71.4000015258789|
# |2019-04-25 00:00:00| 66.85|  62.6|64.74| 65.0| 3863300|     65.0|        ZOOM|64.73999786376953|
# |2019-04-26 00:00:00| 66.99|  63.6|66.12|66.22| 1527400|    66.22|        ZOOM|66.12000274658203|
# |2019-04-29 00:00:00|  68.5| 64.75|66.53|68.17| 1822300|    68.17|        ZOOM|66.52999877929688|
# |2019-04-30 00:00:00| 72.52| 66.67| 68.4|72.47| 4113100|    72.47|        ZOOM| 68.4000015258789|
# |2019-05-01 00:00:00| 76.95|70.816|72.72|72.76| 3301900|    72.76|        ZOOM|72.72000122070312|
# |2019-05-02 00:00:00| 75.89|69.691|72.75| 75.5| 2525300|     75.5|        ZOOM|            72.75|
# +-------------------+------+------+-----+-----+--------+---------+------------+-----------------+
# only showing top 10 rows
#
#
# CORRELATION BETWEEN DIFFERENT STOCKS
#
# Correlation between amazon & apple:
# High & High2 : 0.9297874259390847
# Low & Low2 : 0.9294547100635051
# Open & Open2 : 0.929432373427345
# Close & Close2 : 0.9292860084204524
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.9314678774869076
#
# Correlation between amazon & facebook:
# High & High2 : 0.8682214375390286
# Low & Low2 : 0.858656263465311
# Open & Open2 : 0.8630665010422292
# Close & Close2 : 0.8628112282541691
# Volume & Volume2 : 0.5107653647271243
# Adj Close & AdjClose2 : 0.8628112282541691
#
# Correlation between amazon & google:
# High & High2 : 0.9279218467592136
# Low & Low2 : 0.9238630174063731
# Open & Open2 : 0.9262870255493186
# Close & Close2 : 0.9255061932293708
# Volume & Volume2 : 0.6104197582530982
# Adj Close & AdjClose2 : 0.9255061932293708
#
# Correlation between amazon & microsoft:
# High & High2 : 0.951284096151614
# Low & Low2 : 0.9524913662368054
# Open & Open2 : 0.9514272822500527
# Close & Close2 : 0.9519391984487741
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.9511824060153518
#
# Correlation between amazon & tesla:
# High & High2 : 0.8123427553679604
# Low & Low2 : 0.8069472186412819
# Open & Open2 : 0.8100728829691062
# Close & Close2 : 0.8094073996359907
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.8094073996359907
#
# Correlation between amazon & zoom:
# High & High2 : 0.9133082712469004
# Low & Low2 : 0.9140200107429356
# Open & Open2 : 0.9144061918476822
# Close & Close2 : 0.914744271428987
# Volume & Volume2 : 0.34893526694199006
# Adj Close & AdjClose2 : 0.914744271428987
#
# Correlation between apple & facebook:
# High & High2 : 0.912895378181455
# Low & Low2 : 0.9061836311978357
# Open & Open2 : 0.9093706647109683
# Close & Close2 : 0.909143831170847
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.9086533367686319
#
# Correlation between apple & google:
# High & High2 : 0.9250570139204963
# Low & Low2 : 0.9229422544755259
# Open & Open2 : 0.9232986324073348
# Close & Close2 : 0.9238202964706318
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.9246956687641503
#
# Correlation between apple & microsoft:
# High & High2 : 0.9412485224711806
# Low & Low2 : 0.9417320000174492
# Open & Open2 : 0.940544899449
# Close & Close2 : 0.9414663222485514
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.9439920309680077
#
# Correlation between apple & tesla:
# High & High2 : 0.9113585843845249
# Low & Low2 : 0.9083134679329079
# Open & Open2 : 0.9101124008032263
# Close & Close2 : 0.9094872749905819
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.908939847211644
#
# Correlation between apple & zoom:
# High & High2 : 0.8808886369902045
# Low & Low2 : 0.8784167261492821
# Open & Open2 : 0.8794186794999088
# Close & Close2 : 0.8798818350347076
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.8822159457571348
#
# Correlation between facebook & google:
# High & High2 : 0.9013204763144368
# Low & Low2 : 0.8985141699549771
# Open & Open2 : 0.8993882249308792
# Close & Close2 : 0.9000839548151618
# Volume & Volume2 : 0.46201571804233715
# Adj Close & AdjClose2 : 0.9000839548151618
#
# Correlation between facebook & microsoft:
# High & High2 : 0.8611344337622792
# Low & Low2 : 0.853161152499042
# Open & Open2 : 0.8567486831660741
# Close & Close2 : 0.8570760230066189
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.8556526821290147
#
# Correlation between facebook & tesla:
# High & High2 : 0.8331028488431108
# Low & Low2 : 0.8246657984737641
# Open & Open2 : 0.8286301094216965
# Close & Close2 : 0.8288057479037657
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.8288057479037657
#
# Correlation between facebook & zoom:
# High & High2 : 0.8549963510605557
# Low & Low2 : 0.8442544993637039
# Open & Open2 : 0.851767510593323
# Close & Close2 : 0.8500061058765412
# Volume & Volume2 : 0.2910013298017762
# Adj Close & AdjClose2 : 0.8500061058765412
#
# Correlation between google & microsoft:
# High & High2 : 0.9453856481181697
# Low & Low2 : 0.942653299169456
# Open & Open2 : 0.9442185369519542
# Close & Close2 : 0.9442882610519647
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.9433944144632486
#
# Correlation between google & tesla:
# High & High2 : 0.7712390089726987
# Low & Low2 : 0.7631472893662992
# Open & Open2 : 0.7666815667279554
# Close & Close2 : 0.7665494283405445
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.7665494283405445
#
# Correlation between google & zoom:
# High & High2 : 0.7498826496251751
# Low & Low2 : 0.7311612333480673
# Open & Open2 : 0.7419145392050145
# Close & Close2 : 0.7405503876943942
# Volume & Volume2 : 0.36087726939600523
# Adj Close & AdjClose2 : 0.7405503876943942
#
# Correlation between microsoft & tesla:
# High & High2 : 0.7743821540247339
# Low & Low2 : 0.7703609856919504
# Open & Open2 : 0.7719231288541617
# Close & Close2 : 0.7720378958676984
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.7718157786620587
#
# Correlation between microsoft & zoom:
# High & High2 : 0.842943435742423
# Low & Low2 : 0.8431835101596402
# Open & Open2 : 0.8420396419988482
# Close & Close2 : 0.8431651966720145
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.8451039311151026
#
# Correlation between tesla & zoom:
# High & High2 : 0.9406250294875865
# Low & Low2 : 0.9448065212915425
# Open & Open2 : 0.9426038471310438
# Close & Close2 : 0.9431541228015273
# Volume & Volume2 : nan
# Adj Close & AdjClose2 : 0.9431541228015273
#
# RATE OF RETURN (AMAZON) FROM 03-01-2017 TO 21-01-2017
# (7.568087354878227, 'AMAZON')
# BEST RATE OF RETURN (ALL STOCKS) FROM 07-01-2017 TO A PERIOD OF 1 YEAR 4 WEEKS
# Period between 2017-01-07 00:00:00 - 2018-02-04 00:00:00
# Max rate of return on Open: 85.13659331434053 - AMAZON
# Max rate of return on Close: 79.43457082730548 - AMAZON
# Max rate of return on High: 86.83661941809656 - AMAZON
# Max rate of return on Low: 78.58721157908045 - AMAZON
# Max rate of return on Adj close: 79.43457082730548 - AMAZON

# %% [markdown]
# #Insights

# %%
amazon_path = "stocks_data/AMAZON.csv"
apple_path = "stocks_data/APPLE.csv"
facebook_path = "stocks_data/FACEBOOK.csv"
google_path = "stocks_data/GOOGLE.csv"
microsoft_path = "stocks_data/MICROSOFT.csv"
tesla_path = "stocks_data/TESLA.csv"
zoom_path = "stocks_data/ZOOM.csv"
amazon = read_disp_info(amazon_path)
apple = read_disp_info(apple_path)
facebook = read_disp_info(facebook_path)
google = read_disp_info(google_path)
microsoft = read_disp_info(microsoft_path)
tesla = read_disp_info(tesla_path)
zoom = read_disp_info(zoom_path)
list_df = [amazon, apple, facebook, google, microsoft, tesla, zoom]
list_name = ['amazon', 'apple', 'facebook', 'google', 'microsoft', 'tesla', 'zoom']
# Out:
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=758.760009765625, Low=747.7000122070312, Open=757.9199829101562, Close=753.6699829101562, Volume=3521100, Adj Close=753.6699829101562, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=759.6799926757812, Low=754.2000122070312, Open=758.3900146484375, Close=757.1799926757812, Volume=2510500, Adj Close=757.1799926757812, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=782.4000244140625, Low=760.260009765625, Open=761.5499877929688, Close=780.4500122070312, Volume=5830100, Adj Close=780.4500122070312, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=799.4400024414062, Low=778.47998046875, Open=782.3599853515625, Close=795.989990234375, Volume=5986200, Adj Close=795.989990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=801.77001953125, Low=791.77001953125, Open=798.0, Close=796.9199829101562, Volume=3446100, Adj Close=796.9199829101562, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=798.0, Low=789.5399780273438, Open=796.5999755859375, Close=795.9000244140625, Volume=2558400, Adj Close=795.9000244140625, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=799.5, Low=789.510009765625, Open=793.6599731445312, Close=799.02001953125, Volume=2992800, Adj Close=799.02001953125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=814.1300048828125, Low=799.5, Open=800.3099975585938, Close=813.6400146484375, Volume=4873900, Adj Close=813.6400146484375, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=821.6500244140625, Low=811.4000244140625, Open=814.3200073242188, Close=817.1400146484375, Volume=3791900, Adj Close=817.1400146484375, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=816.0, Low=803.4400024414062, Open=815.7000122070312, Close=809.719970703125, Volume=3670500, Adj Close=809.719970703125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=811.72998046875, Low=804.27001953125, Open=809.5, Close=807.47998046875, Volume=2354200, Adj Close=807.47998046875, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=813.510009765625, Low=807.3200073242188, Open=810.0, Close=809.0399780273438, Volume=2540800, Adj Close=809.0399780273438, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=816.02001953125, Low=806.260009765625, Open=815.280029296875, Close=808.3300170898438, Volume=3376200, Adj Close=808.3300170898438, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=818.5, Low=805.0800170898438, Open=806.7999877929688, Close=817.8800048828125, Volume=2797500, Adj Close=817.8800048828125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=823.989990234375, Low=814.5, Open=822.0, Close=822.4400024414062, Volume=2971700, Adj Close=822.4400024414062, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=837.4199829101562, Low=825.2899780273438, Open=825.7899780273438, Close=836.52001953125, Volume=3922600, Adj Close=836.52001953125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=843.8400268554688, Low=833.0, Open=835.530029296875, Close=839.1500244140625, Volume=3586300, Adj Close=839.1500244140625, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=839.7000122070312, Low=829.4400024414062, Open=839.0, Close=835.77001953125, Volume=2998700, Adj Close=835.77001953125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=833.5, Low=816.3800048828125, Open=833.0, Close=830.3800048828125, Volume=3747300, Adj Close=830.3800048828125, company_name='AMAZON'), Row(Date=datetime.datetime(2017, 1, 31, 0, 0), High=826.989990234375, Low=819.5599975585938, Open=823.75, Close=823.47998046875, Volume=3137200, Adj Close=823.47998046875, company_name ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=3200.0, Low=3132.389892578125, Open=3135.0, Close=3195.68994140625, Volume=4309400, Adj Close=3195.68994140625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=3233.2900390625, Low=3174.989990234375, Open=3224.989990234375, Close=3190.550048828125, Volume=3174100, Adj Close=3190.550048828125, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=3288.989990234375, Low=3197.830078125, Open=3210.0, Close=3286.64990234375, Volume=4907900, Adj Close=3286.64990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=3496.239990234375, Low=3339.550048828125, Open=3349.93994140625, Close=3442.929931640625, Volume=8364200, Adj Close=3442.929931640625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=3492.3798828125, Low=3424.219970703125, Open=3467.989990234375, Close=3443.6298828125, Volume=5744700, Adj Close=3443.6298828125, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=3464.8798828125, Low=3340.0, Open=3447.0, Close=3363.7099609375, Volume=5828900, Adj Close=3363.7099609375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=3355.8798828125, Low=3280.0, Open=3292.010009765625, Close=3338.64990234375, Volume=5223400, Adj Close=3338.64990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=3399.659912109375, Low=3160.0, Open=3363.22998046875, Close=3272.7099609375, Volume=6474400, Adj Close=3272.7099609375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=3329.0, Low=3192.739990234375, Open=3299.610107421875, Close=3207.2099609375, Volume=5223600, Adj Close=3207.2099609375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=3266.0, Low=3192.010009765625, Open=3222.280029296875, Close=3217.010009765625, Volume=4509700, Adj Close=3217.010009765625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=3233.8798828125, Low=3160.0, Open=3212.5, Close=3184.93994140625, Volume=4592700, Adj Close=3184.93994140625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=3198.75, Low=3121.93994140625, Open=3189.8701171875, Close=3176.39990234375, Volume=4212000, Adj Close=3176.39990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=3205.330078125, Low=3140.0, Open=3191.0, Close=3204.39990234375, Volume=3466700, Adj Close=3204.39990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=3282.97998046875, Low=3153.300048828125, Open=3198.739990234375, Close=3207.0400390625, Volume=5901200, Adj Close=3207.0400390625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=3291.659912109375, Low=3211.300048828125, Open=3224.93994140625, Close=3286.330078125, Volume=4291000, Adj Close=3286.330078125, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=3264.02001953125, Low=3162.469970703125, Open=3249.300048828125, Close=3162.780029296875, Volume=5588300, Adj Close=3162.780029296875, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=3257.25, Low=3164.0, Open=3201.27001953125, Close=3211.010009765625, Volume=6596500, Adj Close=3211.010009765625, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=3167.0, Low=3019.0, Open=3157.75, Close=3036.14990234375, Volume=8386400, Adj Close=3036.14990234375, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=3079.7099609375, Low=2950.1201171875, Open=3061.739990234375, Close=3004.47998046875, Volume=7257400, Adj Close=3004.47998046875, company_name='AMAZON'), Row(Date=datetime.datetime(2020, 11, 3, 0, 0), High=3074.89990234375, Low=2980.97998046875, Open=3018.530029296875, Close=3048.409912109375, Volume=4897900, Adj Close=3048.409912109375, company_name='AMAZON'), Row(Date=datetime.datet ...
# 987
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=29.082500457763672, Low=28.690000534057617, Open=28.950000762939453, Close=29.037500381469727, Volume=None, Adj Close=27.277639389038086, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=29.127500534057617, Low=28.9375, Open=28.962499618530273, Close=29.0049991607666, Volume=None, Adj Close=27.247108459472656, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=29.21500015258789, Low=28.952499389648438, Open=28.979999542236328, Close=29.15250015258789, Volume=None, Adj Close=27.38566780090332, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=29.540000915527344, Low=29.11750030517578, Open=29.19499969482422, Close=29.477500915527344, Volume=None, Adj Close=27.69097137451172, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=29.857500076293945, Low=29.485000610351562, Open=29.487499237060547, Close=29.747499465942383, Volume=None, Adj Close=27.944602966308594, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=29.844999313354492, Low=29.575000762939453, Open=29.6924991607666, Close=29.77750015258789, Volume=None, Adj Close=27.97278594970703, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=29.982500076293945, Low=29.649999618530273, Open=29.684999465942383, Close=29.9375, Volume=None, Adj Close=28.123088836669922, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=29.825000762939453, Low=29.552499771118164, Open=29.725000381469727, Close=29.8125, Volume=None, Adj Close=28.005664825439453, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=29.905000686645508, Low=29.702499389648438, Open=29.77750015258789, Close=29.760000228881836, Volume=None, Adj Close=27.956350326538086, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=30.059999465942383, Low=29.55500030517578, Open=29.584999084472656, Close=30.0, Volume=None, Adj Close=28.181800842285156, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=30.125, Low=29.927499771118164, Open=30.0, Close=29.997499465942383, Volume=None, Adj Close=28.17945671081543, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=30.022499084472656, Low=29.842500686645508, Open=29.850000381469727, Close=29.94499969482422, Volume=None, Adj Close=28.1301326751709, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=30.112499237060547, Low=29.9325008392334, Open=30.112499237060547, Close=30.0, Volume=None, Adj Close=28.181800842285156, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=30.202499389648438, Low=29.9424991607666, Open=30.0, Close=30.020000457763672, Volume=None, Adj Close=28.200590133666992, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=30.024999618530273, Low=29.875, Open=29.887500762939453, Close=29.99250030517578, Volume=None, Adj Close=28.17475700378418, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=30.524999618530273, Low=30.06999969482422, Open=30.104999542236328, Close=30.469999313354492, Volume=None, Adj Close=28.623313903808594, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=30.610000610351562, Low=30.399999618530273, Open=30.417499542236328, Close=30.485000610351562, Volume=None, Adj Close=28.637407302856445, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=30.587499618530273, Low=30.399999618530273, Open=30.53499984741211, Close=30.487499237060547, Volume=None, Adj Close=28.639755249023438, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=30.407499313354492, Low=30.165000915527344, Open=30.232500076293945, Close=30.407499313354492, Volume=None, Adj Close=28.564605712890625, company_name='APPLE'), Row(Date=datetime.datetime(2017, 1, 31, 0, 0), High=30.34749984741211, Low=30.155000686645508, O ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=115.55000305175781, Low=114.12999725341797, Open=114.62000274658203, Close=115.08000183105469, Volume=None, Adj Close=114.88180541992188, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=116.4000015258789, Low=114.58999633789062, Open=116.25, Close=114.97000122070312, Volume=None, Adj Close=114.77198791503906, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=117.0, Low=114.91999816894531, Open=115.27999877929688, Close=116.97000122070312, Volume=None, Adj Close=116.76854705810547, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=125.18000030517578, Low=119.27999877929688, Open=120.05999755859375, Close=124.4000015258789, Volume=None, Adj Close=124.18575286865234, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=125.38999938964844, Low=119.6500015258789, Open=125.2699966430664, Close=121.0999984741211, Volume=None, Adj Close=120.89143371582031, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=123.02999877929688, Low=119.62000274658203, Open=121.0, Close=121.19000244140625, Volume=None, Adj Close=120.98127746582031, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=121.19999694824219, Low=118.1500015258789, Open=118.72000122070312, Close=120.70999908447266, Volume=None, Adj Close=120.50210571289062, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=121.55000305175781, Low=118.80999755859375, Open=121.27999877929688, Close=119.0199966430664, Volume=None, Adj Close=118.81501007080078, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=120.41999816894531, Low=115.66000366210938, Open=119.95999908447266, Close=115.9800033569336, Volume=None, Adj Close=115.7802505493164, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=118.9800033569336, Low=115.62999725341797, Open=116.19999694824219, Close=117.51000213623047, Volume=None, Adj Close=117.3076171875, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=118.70999908447266, Low=116.44999694824219, Open=116.66999816894531, Close=116.87000274658203, Volume=None, Adj Close=116.6687240600586, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=118.04000091552734, Low=114.58999633789062, Open=117.44999694824219, Close=115.75, Volume=None, Adj Close=115.55064392089844, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=116.55000305175781, Low=114.27999877929688, Open=116.38999938964844, Close=115.04000091552734, Volume=None, Adj Close=114.84187316894531, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=116.55000305175781, Low=112.87999725341797, Open=114.01000213623047, Close=115.05000305175781, Volume=None, Adj Close=114.85185241699219, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=117.27999877929688, Low=114.54000091552734, Open=115.48999786376953, Close=116.5999984741211, Volume=None, Adj Close=116.39917755126953, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=115.43000030517578, Low=111.0999984741211, Open=115.05000305175781, Close=111.19999694824219, Volume=None, Adj Close=111.00847625732422, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=116.93000030517578, Low=112.19999694824219, Open=112.37000274658203, Close=115.31999969482422, Volume=None, Adj Close=115.12138366699219, company_name='APPLE'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=111.98999786376953, Low=107.72000122070312, Open=111.05999755859375, Close=108.86000061035156, Volume=None, Adj Close=108.67251586914062, company_name='APPLE'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=110.68000030517578, Low=107.31999969482422, Open=109.11000061035156, Close=108.7699966430664, Volume=None, Adj Close=108.5826644897461, company_name='APPLE'), Row(Da ...
# 987
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=117.83999633789062, Low=115.51000213623047, Open=116.02999877929688, Close=116.86000061035156, Volume=20663900, Adj Close=116.86000061035156, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=119.66000366210938, Low=117.29000091552734, Open=117.55000305175781, Close=118.69000244140625, Volume=19630900, Adj Close=118.69000244140625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=120.94999694824219, Low=118.31999969482422, Open=118.86000061035156, Close=120.66999816894531, Volume=19492200, Adj Close=120.66999816894531, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=123.87999725341797, Low=120.02999877929688, Open=120.9800033569336, Close=123.41000366210938, Volume=28545300, Adj Close=123.41000366210938, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=125.43000030517578, Low=123.04000091552734, Open=123.55000305175781, Close=124.9000015258789, Volume=22880400, Adj Close=124.9000015258789, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=125.5, Low=124.27999877929688, Open=124.81999969482422, Close=124.3499984741211, Volume=17324600, Adj Close=124.3499984741211, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=126.12000274658203, Low=124.05999755859375, Open=124.3499984741211, Close=126.08999633789062, Volume=18356500, Adj Close=126.08999633789062, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=126.7300033569336, Low=124.80000305175781, Open=125.61000061035156, Close=126.62000274658203, Volume=18653900, Adj Close=126.62000274658203, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=129.27000427246094, Low=127.37000274658203, Open=127.48999786376953, Close=128.33999633789062, Volume=24884300, Adj Close=128.33999633789062, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=128.33999633789062, Low=127.4000015258789, Open=128.0399932861328, Close=127.87000274658203, Volume=15294500, Adj Close=127.87000274658203, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=128.42999267578125, Low=126.83999633789062, Open=128.41000366210938, Close=127.91999816894531, Volume=13145900, Adj Close=127.91999816894531, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=128.35000610351562, Low=127.44999694824219, Open=128.22999572753906, Close=127.55000305175781, Volume=12195500, Adj Close=127.55000305175781, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=128.47999572753906, Low=126.77999877929688, Open=128.10000610351562, Close=127.04000091552734, Volume=19097200, Adj Close=127.04000091552734, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=129.25, Low=126.94999694824219, Open=127.30999755859375, Close=128.92999267578125, Volume=16593600, Adj Close=128.92999267578125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=129.89999389648438, Low=128.3800048828125, Open=129.3800048828125, Close=129.3699951171875, Volume=15162700, Adj Close=129.3699951171875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=131.74000549316406, Low=129.77000427246094, Open=130.0, Close=131.47999572753906, Volume=18731300, Adj Close=131.47999572753906, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=133.13999938964844, Low=131.44000244140625, Open=131.6300048828125, Close=132.77999877929688, Volume=20020100, Adj Close=132.77999877929688, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=132.9499969482422, Low=131.0800018310547, Open=132.67999267578125, Close=132.17999267578125, Volume=19539500, Adj Close=132.17999267578125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=131.5800018310547, Low=129.60000610351562, Ope ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=260.17999267578125, Low=254.82000732421875, Open=259.2099914550781, Close=258.1199951171875, Volume=23133400, Adj Close=258.1199951171875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=264.6199951171875, Low=259.1499938964844, Open=259.75, Close=263.760009765625, Volume=16312800, Adj Close=263.760009765625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=264.75, Low=262.1700134277344, Open=264.5199890136719, Close=264.45001220703125, Volume=14107800, Adj Close=264.45001220703125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=280.17999267578125, Low=267.8699951171875, Open=270.20001220703125, Close=275.75, Volume=31019300, Adj Close=275.75, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=279.1000061035156, Low=273.3900146484375, Open=277.5799865722656, Close=276.1400146484375, Volume=18063300, Adj Close=276.1400146484375, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=278.75, Low=271.5, Open=277.6199951171875, Close=271.82000732421875, Volume=15601200, Adj Close=271.82000732421875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=269.0400085449219, Low=263.6700134277344, Open=267.6000061035156, Close=266.7200012207031, Volume=15416100, Adj Close=266.7200012207031, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=271.3699951171875, Low=265.29998779296875, Open=267.3800048828125, Close=265.92999267578125, Volume=16622700, Adj Close=265.92999267578125, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=268.54998779296875, Low=259.8800048828125, Open=265.5299987792969, Close=261.3999938964844, Volume=13587000, Adj Close=261.3999938964844, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=269.70001220703125, Low=262.8800048828125, Open=263.05999755859375, Close=267.55999755859375, Volume=18763200, Adj Close=267.55999755859375, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=283.04998779296875, Low=276.3699951171875, Open=279.55999755859375, Close=278.7300109863281, Volume=28998600, Adj Close=278.7300109863281, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=282.45001220703125, Low=275.0400085449219, Open=279.8699951171875, Close=278.1199951171875, Volume=16720000, Adj Close=278.1199951171875, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=285.239990234375, Low=276.82000732421875, Open=278.79998779296875, Close=284.7900085449219, Volume=17535200, Adj Close=284.7900085449219, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=285.2300109863281, Low=274.260009765625, Open=283.1600036621094, Close=277.1099853515625, Volume=21322900, Adj Close=277.1099853515625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=284.510009765625, Low=276.30999755859375, Open=278.760009765625, Close=283.2900085449219, Volume=16287200, Adj Close=283.2900085449219, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=278.7900085449219, Low=267.260009765625, Open=278.7900085449219, Close=267.6700134277344, Volume=23121800, Adj Close=267.6700134277344, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=283.6000061035156, Low=273.7799987792969, Open=276.54998779296875, Close=280.8299865722656, Volume=32368100, Adj Close=280.8299865722656, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=276.70001220703125, Low=259.1000061035156, Open=274.5, Close=263.1099853515625, Volume=47247800, Adj Close=263.1099853515625, company_name='FACEBOOK'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=270.4700012207031, Low=257.3399963378906, Open=264.6000061035156, Close=261.3599853515625, Volume=27165700, Adj Close=261.35 ...
# 987
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=789.6300048828125, Low=775.7999877929688, Open=778.8099975585938, Close=786.1400146484375, Volume=1657300, Adj Close=786.1400146484375, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=791.3400268554688, Low=783.1599731445312, Open=788.3599853515625, Close=786.9000244140625, Volume=1073000, Adj Close=786.9000244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=794.47998046875, Low=785.02001953125, Open=786.0800170898438, Close=794.02001953125, Volume=1335200, Adj Close=794.02001953125, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=807.9000244140625, Low=792.2039794921875, Open=795.260009765625, Close=806.1500244140625, Volume=1640200, Adj Close=806.1500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=809.9660034179688, Low=802.8300170898438, Open=806.4000244140625, Close=806.6500244140625, Volume=1274600, Adj Close=806.6500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=809.1300048828125, Low=803.510009765625, Open=807.8599853515625, Close=804.7899780273438, Volume=1176800, Adj Close=804.7899780273438, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=808.1500244140625, Low=801.3699951171875, Open=805.0, Close=807.9099731445312, Volume=1065900, Adj Close=807.9099731445312, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=807.3900146484375, Low=799.1699829101562, Open=807.1400146484375, Close=806.3599853515625, Volume=1353100, Adj Close=806.3599853515625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=811.2239990234375, Low=806.6900024414062, Open=807.47998046875, Close=807.8800048828125, Volume=1099200, Adj Close=807.8800048828125, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=807.1400146484375, Low=800.3699951171875, Open=807.0800170898438, Close=804.6099853515625, Volume=1362100, Adj Close=804.6099853515625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=806.2050170898438, Low=800.989990234375, Open=805.8099975585938, Close=806.0700073242188, Volume=1294400, Adj Close=806.0700073242188, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=809.47998046875, Low=801.7999877929688, Open=805.1199951171875, Close=802.1749877929688, Volume=919300, Adj Close=802.1749877929688, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=806.9099731445312, Low=801.6900024414062, Open=806.9099731445312, Close=805.02001953125, Volume=1670000, Adj Close=805.02001953125, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=820.8699951171875, Low=803.739990234375, Open=807.25, Close=819.3099975585938, Volume=1963600, Adj Close=819.3099975585938, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=825.9000244140625, Low=817.8209838867188, Open=822.2999877929688, Close=823.8699951171875, Volume=1474000, Adj Close=823.8699951171875, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=835.77001953125, Low=825.0599975585938, Open=829.6199951171875, Close=835.6699829101562, Volume=1494500, Adj Close=835.6699829101562, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=838.0, Low=827.010009765625, Open=837.8099975585938, Close=832.1500244140625, Volume=2973900, Adj Close=832.1500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=841.9500122070312, Low=820.4400024414062, Open=834.7100219726562, Close=823.3099975585938, Volume=2965800, Adj Close=823.3099975585938, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=815.8400268554688, Low=799.7999877929688, Open=814.6599731445312, Close=802.3200073242188, Volume=3246600, Adj Close=802.3200073242188, company_name='GOOGLE'), Row(Date=datetime.datetime(2017, 1, ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=1468.9599609375, Low=1436.0, Open=1464.2900390625, Close=1460.2900390625, Volume=1746200, Adj Close=1460.2900390625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=1490.0, Low=1465.0899658203125, Open=1465.0899658203125, Close=1485.9300537109375, Volume=1187800, Adj Close=1485.9300537109375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=1516.52001953125, Low=1489.449951171875, Open=1494.699951171875, Close=1515.219970703125, Volume=1435300, Adj Close=1515.219970703125, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=1593.8599853515625, Low=1532.5699462890625, Open=1543.0, Close=1569.1500244140625, Volume=2482600, Adj Close=1569.1500244140625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=1590.0, Low=1563.199951171875, Open=1583.72998046875, Close=1571.6800537109375, Volume=1601000, Adj Close=1571.6800537109375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=1587.6839599609375, Low=1550.530029296875, Open=1578.5899658203125, Close=1568.0799560546875, Volume=1931000, Adj Close=1568.0799560546875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=1575.10498046875, Low=1545.030029296875, Open=1547.1500244140625, Close=1559.1300048828125, Volume=1540000, Adj Close=1559.1300048828125, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=1581.1300048828125, Low=1563.0, Open=1565.8499755859375, Close=1573.010009765625, Volume=1434700, Adj Close=1573.010009765625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=1588.1500244140625, Low=1528.0, Open=1580.4599609375, Close=1534.6099853515625, Volume=1607100, Adj Close=1534.6099853515625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=1577.5, Low=1525.6700439453125, Open=1527.050048828125, Close=1555.9300537109375, Volume=2241700, Adj Close=1555.9300537109375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=1618.72998046875, Low=1571.6300048828125, Open=1573.3299560546875, Close=1593.31005859375, Volume=2568300, Adj Close=1593.31005859375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=1621.989990234375, Low=1585.0, Open=1593.050048828125, Close=1615.3299560546875, Volume=1433600, Adj Close=1615.3299560546875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=1642.3599853515625, Low=1620.510009765625, Open=1626.0699462890625, Close=1641.0, Volume=1375800, Adj Close=1641.0, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=1638.239990234375, Low=1576.5, Open=1625.010009765625, Close=1590.449951171875, Volume=1853300, Adj Close=1590.449951171875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=1606.844970703125, Low=1582.780029296875, Open=1595.6700439453125, Close=1604.260009765625, Volume=1229000, Adj Close=1604.260009765625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=1561.3499755859375, Low=1514.6199951171875, Open=1559.739990234375, Close=1516.6199951171875, Volume=1834000, Adj Close=1516.6199951171875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=1593.7099609375, Low=1522.239990234375, Open=1522.3599853515625, Close=1567.239990234375, Volume=2003100, Adj Close=1567.239990234375, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=1687.0, Low=1604.4599609375, Open=1672.1099853515625, Close=1621.010009765625, Volume=4329100, Adj Close=1621.010009765625, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=1660.77001953125, Low=1616.030029296875, Open=1628.1600341796875, Close=1626.030029296875, Volume=2535400, Adj Close=1626.030029296875, company_name='GOOGLE'), Row(Date=datetime.datetime(2020, 11, 3, 0, 0), High=1661.699951171875, ...
# 987
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=62.84000015258789, Low=62.130001068115234, Open=62.790000915527344, Close=62.58000183105469, Volume=None, Adj Close=58.67324447631836, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=62.75, Low=62.119998931884766, Open=62.47999954223633, Close=62.29999923706055, Volume=None, Adj Close=58.41072463989258, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=62.65999984741211, Low=62.029998779296875, Open=62.189998626708984, Close=62.29999923706055, Volume=None, Adj Close=58.41072463989258, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=63.150001525878906, Low=62.040000915527344, Open=62.29999923706055, Close=62.84000015258789, Volume=None, Adj Close=58.917015075683594, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=63.08000183105469, Low=62.540000915527344, Open=62.7599983215332, Close=62.63999938964844, Volume=None, Adj Close=58.729496002197266, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=63.06999969482422, Low=62.279998779296875, Open=62.72999954223633, Close=62.619998931884766, Volume=None, Adj Close=58.71074676513672, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=63.22999954223633, Low=62.43000030517578, Open=62.61000061035156, Close=63.189998626708984, Volume=None, Adj Close=59.24515914916992, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=63.400001525878906, Low=61.95000076293945, Open=63.060001373291016, Close=62.61000061035156, Volume=None, Adj Close=58.70137023925781, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=62.869998931884766, Low=62.349998474121094, Open=62.619998931884766, Close=62.70000076293945, Volume=None, Adj Close=58.7857551574707, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=62.70000076293945, Low=62.029998779296875, Open=62.68000030517578, Close=62.529998779296875, Volume=None, Adj Close=58.62636947631836, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=62.70000076293945, Low=62.119998931884766, Open=62.66999816894531, Close=62.5, Volume=None, Adj Close=58.59824752807617, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=62.97999954223633, Low=62.20000076293945, Open=62.2400016784668, Close=62.29999923706055, Volume=None, Adj Close=58.41072463989258, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=62.81999969482422, Low=62.369998931884766, Open=62.66999816894531, Close=62.7400016784668, Volume=None, Adj Close=58.82326126098633, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=63.119998931884766, Low=62.56999969482422, Open=62.70000076293945, Close=62.959999084472656, Volume=None, Adj Close=59.02952575683594, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=63.7400016784668, Low=62.939998626708984, Open=63.20000076293945, Close=63.52000045776367, Volume=None, Adj Close=59.554569244384766, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=64.0999984741211, Low=63.45000076293945, Open=63.95000076293945, Close=63.68000030517578, Volume=None, Adj Close=59.70457458496094, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=64.54000091552734, Low=63.54999923706055, Open=64.12000274658203, Close=64.2699966430664, Volume=None, Adj Close=60.25773620605469, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=65.91000366210938, Low=64.88999938964844, Open=65.38999938964844, Close=65.77999877929688, Volume=None, Adj Close=61.67348098754883, company_name='MICROSOFT'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=65.79000091552734, Low=64.80000305175781, Open=65.69000244140625, Close=65.12999725341797, Volume=None, Adj Close=61.06404495239258, company_n ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=210.11000061035156, Low=206.72000122070312, Open=207.05999755859375, Close=209.8300018310547, Volume=None, Adj Close=209.28208923339844, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=211.19000244140625, Low=208.32000732421875, Open=210.50999450683594, Close=210.5800018310547, Volume=None, Adj Close=210.03013610839844, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=215.86000061035156, Low=211.22999572753906, Open=211.22999572753906, Close=215.80999755859375, Volume=None, Adj Close=215.24647521972656, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=223.86000061035156, Low=216.80999755859375, Open=218.7899932861328, Close=221.39999389648438, Volume=None, Adj Close=220.82186889648438, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=225.2100067138672, Low=220.42999267578125, Open=222.72000122070312, Close=222.86000061035156, Volume=None, Adj Close=222.27806091308594, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=224.22000122070312, Low=219.1300048828125, Open=223.0, Close=220.86000061035156, Volume=None, Adj Close=220.2832794189453, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=220.36000061035156, Low=216.00999450683594, Open=217.10000610351562, Close=219.66000366210938, Volume=None, Adj Close=219.08642578125, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=222.2899932861328, Low=219.32000732421875, Open=220.14999389648438, Close=219.66000366210938, Volume=None, Adj Close=219.08642578125, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=222.3000030517578, Low=213.72000122070312, Open=220.4199981689453, Close=214.22000122070312, Volume=None, Adj Close=213.66062927246094, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=217.3699951171875, Low=213.08999633789062, Open=215.8000030517578, Close=214.64999389648438, Volume=None, Adj Close=214.08949279785156, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=216.9199981689453, Low=213.1199951171875, Open=213.1199951171875, Close=214.8000030517578, Volume=None, Adj Close=214.23912048339844, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=216.05999755859375, Low=211.6999969482422, Open=213.92999267578125, Close=214.88999938964844, Volume=None, Adj Close=214.32887268066406, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=216.27999877929688, Low=213.16000366210938, Open=215.02999877929688, Close=216.22999572753906, Volume=None, Adj Close=215.66537475585938, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=216.33999633789062, Low=208.10000610351562, Open=213.85000610351562, Close=210.0800018310547, Volume=None, Adj Close=209.53143310546875, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=214.6699981689453, Low=210.3300018310547, Open=211.58999633789062, Close=213.25, Volume=None, Adj Close=212.6931610107422, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=208.83999633789062, Low=202.10000610351562, Open=207.6699981689453, Close=202.67999267578125, Volume=None, Adj Close=202.1507568359375, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=207.36000061035156, Low=203.3699951171875, Open=204.07000732421875, Close=204.72000122070312, Volume=None, Adj Close=204.1854248046875, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=204.2899932861328, Low=199.6199951171875, Open=203.5, Close=202.47000122070312, Volume=None, Adj Close=201.94131469726562, company_name='MICROSOFT'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=205.27999877929688, Low=200.1199951171875, Open=204.2899932861328, Close=202.3300018310547, Volu ...
# 987
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2017, 1, 3, 0, 0), High=44.066001892089844, Low=42.19200134277344, Open=42.97200012207031, Close=43.39799880981445, Volume=None, Adj Close=43.39799880981445, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 4, 0, 0), High=45.599998474121094, Low=42.86199951171875, Open=42.95000076293945, Close=45.39799880981445, Volume=None, Adj Close=45.39799880981445, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 5, 0, 0), High=45.49599838256836, Low=44.38999938964844, Open=45.284000396728516, Close=45.349998474121094, Volume=None, Adj Close=45.349998474121094, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 6, 0, 0), High=46.0620002746582, Low=45.09000015258789, Open=45.38600158691406, Close=45.801998138427734, Volume=None, Adj Close=45.801998138427734, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 9, 0, 0), High=46.38399887084961, Low=45.599998474121094, Open=45.79399871826172, Close=46.25600051879883, Volume=None, Adj Close=46.25600051879883, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 10, 0, 0), High=46.400001525878906, Low=45.37799835205078, Open=46.400001525878906, Close=45.9739990234375, Volume=None, Adj Close=45.9739990234375, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 11, 0, 0), High=45.99599838256836, Low=45.33599853515625, Open=45.81399917602539, Close=45.94599914550781, Volume=None, Adj Close=45.94599914550781, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 12, 0, 0), High=46.13999938964844, Low=45.11600112915039, Open=45.8120002746582, Close=45.917999267578125, Volume=None, Adj Close=45.917999267578125, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 13, 0, 0), High=47.56999969482422, Low=45.917999267578125, Open=46.0, Close=47.54999923706055, Volume=None, Adj Close=47.54999923706055, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 17, 0, 0), High=47.992000579833984, Low=46.874000549316406, Open=47.34000015258789, Close=47.11600112915039, Volume=None, Adj Close=47.11600112915039, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 18, 0, 0), High=47.94200134277344, Low=47.11600112915039, Open=47.33000183105469, Close=47.672000885009766, Volume=None, Adj Close=47.672000885009766, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 19, 0, 0), High=49.736000061035156, Low=48.150001525878906, Open=49.45000076293945, Close=48.75199890136719, Volume=None, Adj Close=48.75199890136719, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 20, 0, 0), High=49.20000076293945, Low=48.60200119018555, Open=49.09199905395508, Close=48.94599914550781, Volume=None, Adj Close=48.94599914550781, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 23, 0, 0), High=50.178001403808594, Low=49.099998474121094, Open=49.16999816894531, Close=49.784000396728516, Volume=None, Adj Close=49.784000396728516, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 24, 0, 0), High=50.959999084472656, Low=49.93000030517578, Open=50.0, Close=50.922000885009766, Volume=None, Adj Close=50.922000885009766, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 25, 0, 0), High=51.69200134277344, Low=50.36000061035156, Open=51.46200180053711, Close=50.89400100708008, Volume=None, Adj Close=50.89400100708008, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 26, 0, 0), High=51.14799880981445, Low=50.150001525878906, Open=50.858001708984375, Close=50.50199890136719, Volume=None, Adj Close=50.50199890136719, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 27, 0, 0), High=50.599998474121094, Low=49.70399856567383, Open=50.2760009765625, Close=50.59000015258789, Volume=None, Adj Close=50.59000015258789, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 30, 0, 0), High=51.05799865722656, Low=49.41999816894531, Open=50.50600051879883, Close=50.125999450683594, Volume=None, Adj Close=50.125999450683594, company_name='TESLA'), Row(Date=datetime.datetime(2017, 1, 31, 0, 0), High= ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=429.8999938964844, Low=413.8500061035156, Open=419.8699951171875, Close=425.29998779296875, Volume=None, Adj Close=425.29998779296875, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=439.0, Low=425.29998779296875, Open=438.44000244140625, Close=425.9200134277344, Volume=None, Adj Close=425.9200134277344, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=434.5899963378906, Low=426.4599914550781, Open=430.1300048828125, Close=434.0, Volume=None, Adj Close=434.0, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=448.739990234375, Low=438.5799865722656, Open=442.0, Close=442.29998779296875, Volume=None, Adj Close=442.29998779296875, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=448.8900146484375, Low=436.6000061035156, Open=443.3500061035156, Close=446.6499938964844, Volume=None, Adj Close=446.6499938964844, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=465.8999938964844, Low=447.3500061035156, Open=449.7799987792969, Close=461.29998779296875, Volume=None, Adj Close=461.29998779296875, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=456.57000732421875, Low=442.5, Open=450.30999755859375, Close=448.8800048828125, Volume=None, Adj Close=448.8800048828125, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=455.95001220703125, Low=438.8500061035156, Open=454.44000244140625, Close=439.6700134277344, Volume=None, Adj Close=439.6700134277344, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=447.0, Low=428.8699951171875, Open=446.239990234375, Close=430.8299865722656, Volume=None, Adj Close=430.8299865722656, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=431.75, Low=419.04998779296875, Open=431.75, Close=421.94000244140625, Volume=None, Adj Close=421.94000244140625, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=432.95001220703125, Low=421.25, Open=422.70001220703125, Close=422.6400146484375, Volume=None, Adj Close=422.6400146484375, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=445.2300109863281, Low=424.510009765625, Open=441.9200134277344, Close=425.7900085449219, Volume=None, Adj Close=425.7900085449219, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=422.8900146484375, Low=407.3800048828125, Open=421.8399963378906, Close=420.6300048828125, Volume=None, Adj Close=420.6300048828125, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=425.760009765625, Low=410.0, Open=411.6300048828125, Close=420.2799987792969, Volume=None, Adj Close=420.2799987792969, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=430.5, Low=420.1000061035156, Open=423.760009765625, Close=424.67999267578125, Volume=None, Adj Close=424.67999267578125, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=418.6000061035156, Low=406.0, Open=416.4800109863281, Close=406.0199890136719, Volume=None, Adj Close=406.0199890136719, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=418.05999755859375, Low=406.4599914550781, Open=409.9599914550781, Close=410.8299865722656, Volume=None, Adj Close=410.8299865722656, company_name='TESLA'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=407.5899963378906, Low=379.1099853515625, Open=406.8999938964844, Close=388.0400085449219, Volume=None, Adj Close=388.0400085449219, company_name='TESLA'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=406.9800109863281, Low=392.29998779296875, Open=394.0, Close=400.510009765625, Volume=None, Adj Close=400.510009765625, company_name='TESLA'), Row(Date=datetime.datetime(2020, 11, 3, 0, 0), High=427.7699890136719, Low=406.69000244140625, Open=409.7300109863281, Close=423.8999938964844, Volume=None, Adj Close=423. ...
# 987
# root
#  |-- Date: timestamp (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- Close: float (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Adj Close: float (nullable = true)
#  |-- company_name: string (nullable = true)
#
# [Row(Date=datetime.datetime(2019, 4, 18, 0, 0), High=66.0, Low=60.32099914550781, Open=65.0, Close=62.0, Volume=25764700, Adj Close=62.0, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 4, 22, 0, 0), High=68.9000015258789, Low=59.939998626708984, Open=61.0, Close=65.69999694824219, Volume=9949700, Adj Close=65.69999694824219, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 4, 23, 0, 0), High=74.16899871826172, Low=65.55000305175781, Open=66.87000274658203, Close=69.0, Volume=6786500, Adj Close=69.0, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 4, 24, 0, 0), High=71.5, Low=63.15999984741211, Open=71.4000015258789, Close=63.20000076293945, Volume=4973500, Adj Close=63.20000076293945, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 4, 25, 0, 0), High=66.8499984741211, Low=62.599998474121094, Open=64.73999786376953, Close=65.0, Volume=3863300, Adj Close=65.0, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 4, 26, 0, 0), High=66.98999786376953, Low=63.599998474121094, Open=66.12000274658203, Close=66.22000122070312, Volume=1527400, Adj Close=66.22000122070312, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 4, 29, 0, 0), High=68.5, Low=64.75, Open=66.52999877929688, Close=68.16999816894531, Volume=1822300, Adj Close=68.16999816894531, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 4, 30, 0, 0), High=72.5199966430664, Low=66.66999816894531, Open=68.4000015258789, Close=72.47000122070312, Volume=4113100, Adj Close=72.47000122070312, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 1, 0, 0), High=76.94999694824219, Low=70.81600189208984, Open=72.72000122070312, Close=72.76000213623047, Volume=3301900, Adj Close=72.76000213623047, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 2, 0, 0), High=75.88999938964844, Low=69.69100189208984, Open=72.75, Close=75.5, Volume=2525300, Adj Close=75.5, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 3, 0, 0), High=80.25, Low=75.0, Open=75.0, Close=79.18000030517578, Volume=2590300, Adj Close=79.18000030517578, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 6, 0, 0), High=80.79000091552734, Low=74.5, Open=75.01000213623047, Close=78.23999786376953, Volume=2051800, Adj Close=78.23999786376953, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 7, 0, 0), High=78.05000305175781, Low=73.25, Open=77.8499984741211, Close=73.33000183105469, Volume=1975200, Adj Close=73.33000183105469, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 8, 0, 0), High=78.5, Low=74.02999877929688, Open=74.61000061035156, Close=77.68000030517578, Volume=2265500, Adj Close=77.68000030517578, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 9, 0, 0), High=76.98999786376953, Low=74.0, Open=76.8499984741211, Close=75.20999908447266, Volume=1348200, Adj Close=75.20999908447266, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 10, 0, 0), High=79.73999786376953, Low=74.7699966430664, Open=75.79000091552734, Close=79.62999725341797, Volume=1555100, Adj Close=79.62999725341797, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 13, 0, 0), High=77.38999938964844, Low=70.5999984741211, Open=77.38999938964844, Close=72.54000091552734, Volume=2873200, Adj Close=72.54000091552734, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 14, 0, 0), High=76.88500213623047, Low=73.11000061035156, Open=74.12000274658203, Close=73.13999938964844, Volume=1950400, Adj Close=73.13999938964844, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 15, 0, 0), High=80.0, Low=72.20999908447266, Open=73.4000015258789, Close=79.76000213623047, Volume=2426500, Adj Close=79.76000213623047, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 16, 0, 0), High=87.55000305175781, Low=79.25, Open=80.12000274658203, Close=83.4000015258789, Volume=4580700, Adj Close=83.4000015258789, company_name='ZOOM'), Row(Date=datetime.datetime(2019, 5, 17, 0, 0), High=90.27999877929688, Low=81.87999725341797, Open=82.25, Close=89.980003 ...
# [Row(Date=datetime.datetime(2020, 10, 7, 0, 0), High=487.5, Low=477.1099853515625, Open=482.5, Close=480.6099853515625, Volume=4449500, Adj Close=480.6099853515625, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 8, 0, 0), High=489.489990234375, Low=475.5799865722656, Open=484.0, Close=478.54998779296875, Volume=4193100, Adj Close=478.54998779296875, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 9, 0, 0), High=498.8999938964844, Low=484.0799865722656, Open=487.989990234375, Close=492.4100036621094, Volume=8719700, Adj Close=492.4100036621094, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 12, 0, 0), High=506.1099853515625, Low=490.4779968261719, Open=501.42999267578125, Close=491.5400085449219, Volume=6979500, Adj Close=491.5400085449219, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 13, 0, 0), High=520.0, Low=493.0, Open=494.0, Close=518.7899780273438, Volume=8941500, Adj Close=518.7899780273438, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 14, 0, 0), High=519.7999877929688, Low=498.6000061035156, Open=518.780029296875, Close=509.25, Volume=8327700, Adj Close=509.25, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 15, 0, 0), High=540.0499877929688, Low=506.5, Open=509.0799865722656, Close=536.4000244140625, Volume=16520600, Adj Close=536.4000244140625, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 16, 0, 0), High=565.4500122070312, Low=543.25, Open=544.0, Close=559.0, Volume=13745800, Adj Close=559.0, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 19, 0, 0), High=588.8400268554688, Low=562.5499877929688, Open=572.5, Close=568.3400268554688, Volume=15193200, Adj Close=568.3400268554688, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 20, 0, 0), High=575.6900024414062, Low=534.5900268554688, Open=572.3300170898438, Close=537.02001953125, Volume=12098200, Adj Close=537.02001953125, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 21, 0, 0), High=551.6599731445312, Low=511.7799987792969, Open=535.8800048828125, Close=513.1900024414062, Volume=9215400, Adj Close=513.1900024414062, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 22, 0, 0), High=530.4299926757812, Low=503.4700012207031, Open=521.780029296875, Close=520.5399780273438, Volume=8100900, Adj Close=520.5399780273438, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 23, 0, 0), High=527.0, Low=505.4100036621094, Open=522.3300170898438, Close=511.5199890136719, Volume=5377100, Adj Close=511.5199890136719, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 26, 0, 0), High=541.10498046875, Low=510.30999755859375, Open=520.489013671875, Close=517.7899780273438, Volume=10080800, Adj Close=517.7899780273438, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 27, 0, 0), High=540.0, Low=513.2999877929688, Open=525.219970703125, Close=538.989990234375, Volume=7227600, Adj Close=538.989990234375, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 28, 0, 0), High=553.8590087890625, Low=511.5, Open=549.5, Close=516.010009765625, Volume=8810100, Adj Close=516.010009765625, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 29, 0, 0), High=525.4550170898438, Low=483.5, Open=521.1900024414062, Close=489.67999267578125, Volume=9207600, Adj Close=489.67999267578125, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 10, 30, 0, 0), High=495.95001220703125, Low=457.0199890136719, Open=481.5, Close=460.9100036621094, Volume=8697800, Adj Close=460.9100036621094, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 11, 2, 0, 0), High=477.0, Low=440.0, Open=462.2900085449219, Close=453.0, Volume=8051900, Adj Close=453.0, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 11, 3, 0, 0), High=461.8800048828125, Low=445.010009765625, Open=456.3280029296875, Close=451.510009765625, Volume=6497000, Adj Close=451.510009765625, company_name='ZOOM'), Row(Date=datetime.datetime(2020, 11, 4, 0, 0), High=484.94000244140625, Low= ...
# 411

# %% [markdown]
# #Bollinger Bands
#
# - Bollinger bands are a type of technical indicator that allows traders to analyze the volatility of a stock and whether the price is high or low on a relative basis
# - The top band is typically two standard deviations above the SMA and the bottom band is typically two standard deviations below the SMA (Simple Moving Average)
# - Some quick observations you can make from looking at this graph is that the closing prices of the stock mostly stay in between both the Bollinger bands. In addition, you can identify buy signals when the price line hits the lower band and sell signals when the price line hits the higher band.

# %%
import matplotlib.pyplot as plt

def moving_average_std(dataframe, column_name, n): 
    w = Window.partitionBy().orderBy(F.col('Date')).rowsBetween(-5, 0)
    dataframe = dataframe.withColumn('moving_average', F.avg(column_name).over(w))
    dataframe = dataframe.withColumn('std', F.stddev('moving_average').over(w)) 
    return dataframe

def bollinger_calculate(df, column_name, n_days):
    return moving_average_std(df, column_name, 100)

def bollinger_bands_plot(df, name):
    closing_prices = df.select('Close').\
        rdd.flatMap(lambda x: x).collect()
    sma = df.select('moving_average').rdd.flatMap(lambda x: x).collect()
    std = df.select('std').rdd.flatMap(lambda x: x).collect()
    bollinger_up = []
    bollinger_down = []
    for avg, dev in zip(sma, std):
        dev = 0 if not dev else dev
        bollinger_up.append(avg + dev * 2)
        bollinger_down.append(avg - dev * 2)
    
    plt.title(name + ' SMA')
    plt.xlabel('Days')
    plt.ylabel('Closing Prices')
    plt.plot(closing_prices, label='Closing Prices')
    plt.plot(bollinger_up, label='Bollinger Up', c='g')
    plt.plot(bollinger_down, label='Bollinger Down', c='r')
    plt.legend()
    plt.show()

def plot_all_bollinger_bands(list_df, list_name, column_name, n_days = 20):
    for df, name in zip(list_df, list_name):
        df_bollinger = bollinger_calculate(df, column_name, n_days)
        bollinger_bands_plot(df_bollinger, name) 


plot_all_bollinger_bands(list_df, list_name, 'Close')

# %% [markdown]
# #Evolution of stocks open prices

# %%
import matplotlib.pyplot as plt

def evolution_stock(list_df, list_name, column_name):
    for df, name in zip(list_df, list_name):
        dates = df.select('Date').rdd.flatMap(lambda x: x).collect()
        prices = df.select(column_name).rdd.flatMap(lambda x: x).collect()
        plt.plot(dates, prices, label=name)
    
    plt.title('Open prices evolution')
    plt.xlabel('Year')
    plt.ylabel(f'{column_name} price')
    plt.legend()
    plt.show()
    
evolution_stock(list_df, list_name, 'Open')

# %% [markdown]
# #Moving Average Convergence Divergence
# Moving average convergence divergence (MACD) is a trend-following momentum indicator that shows the relationship between two moving averages of a security’s price.MACD is calculated by subtracting the long-term EMA (26 periods) from the short-term EMA (12 periods). The result of that calculation is the MACD line. A nine-day EMA of the MACD called the "signal line," is then plotted on top of the MACD line, which can function as a trigger for buy and sell signals. Traders may buy the security when the MACD crosses above its signal line and sell—or short—the security when the MACD crosses below the signal line.

# %% [markdown]
# #Diversification
# Diversification is a risk management strategy that mixes a wide variety of investments within a portfolio. A diversified portfolio contains a mix of distinct asset types and investment vehicles in an attempt at limiting exposure to any single asset or risk. The rationale behind this technique is that a portfolio constructed of different kinds of assets will, on average, yield higher long-term returns and lower the risk of any individual holding or security.

# %% [markdown]
# #Value at Risk
# Value at risk (VaR) is a statistic that quantifies the extent of possible financial losses within a firm, portfolio, or position over a specific time frame. This metric is most commonly used by investment and commercial banks to determine the extent and probabilities of potential losses in their institutional portfolios.
#
# Risk managers use VaR to measure and control the level of risk exposure. One can apply VaR calculations to specific positions or whole portfolios or use them to measure firm-wide risk exposure.

# %% [markdown]
# #Aroon Oscillator
# The Aroon Oscillator is a trend-following indicator that uses aspects of the Aroon Indicator (Aroon Up and Aroon Down) to gauge the strength of a current trend and the likelihood that it will continue. The highs and lows used in the Aroon Up and Aroon Down calculations help to create an inverse relationship between the two indicators. When the Aroon Up value increases, the Aroon Down value will typically see a decrease and vice versa.
#
# When Aroon Up remains high from consecutive new highs, the oscillator value will be high, following the uptrend. When a security’s price is on a downtrend with many new lows, the Aroon Down value will be higher resulting in a lower oscillator value.
